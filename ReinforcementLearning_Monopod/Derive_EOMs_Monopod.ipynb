# %% [markdown]
# # Derive equation of motion of monopod

# %%
# import libraries
import sympy as sym
import numpy as np

sym.init_printing()
from IPython.display import display #for pretty printing

# create symbolic variables

# system parameters
g = sym.symbols('g')
mb,mlt,mlb = sym.symbols(['m_{body}','m_{leg1}','m_{leg2}']) # mass
lb,llt,llb = sym.symbols(['l_{body}','l_{leg1}','l_{leg2}']) # length
Inb,Inlt,Inlb = sym.symbols(['I_{body}','I_{leg1}','I_{leg2}']) # moment of intertia

# generalized coordinates
x,y,thb,thlt,thlb = sym.symbols(['x','y','\\theta_{body}','\\theta_{legtop}','\\theta_{legbot}']) 
dx,dy,dthb,dthlt,dthlb = sym.symbols(['\dot{x}','\dot{y}','\dot{\\theta}_{body}','\dot{\\theta}_{legtop}','\dot{\\theta}_{legbot}']) 
ddx,ddy,ddthb,ddthlt,ddthlb = sym.symbols(['\ddot{x}','\ddot{y}','\ddot{\\theta}_{body}','\ddot{\\theta}_{legtop}','\ddot{\\theta}_{legbot}']) 

q = sym.Matrix([[x],[y],[thb],[thlt],[thlb]])
dq = sym.Matrix([[dx],[dy],[dthb],[dthlt],[dthlb]])
ddq = sym.Matrix([[ddx],[ddy],[ddthb],[ddthlt],[ddthlb]])

# forces
# total joint action = actuator + rebound, but that will be dealt with elsewhere
tauh,tauk,GRFx,GRFy = sym.symbols(['\\tau_{hip}','\\tau_{knee}','G_x','G_y']) 

# STEP 1: position vectors ri = [x,y,theta] (world frame)
rb = sym.Matrix([[x],
                [y],
                [thb]])

rl1 = sym.Matrix([[x + 0.5*llt*sym.sin(thb + thlt)],
                [y - 0.5*llt*sym.cos(thb + thlt)],
                [thb + thlt]])

rl2 = sym.Matrix([[x + llt*sym.sin(thb + thlt)+0.5*llb*sym.sin(thb + thlt + thlb)],
                [y - llt*sym.cos(thb + thlt) - 0.5*llb*sym.cos(thb + thlt + thlb)],
                [thb + thlt + thlb]])

# the Jacobians
Jb = rb.jacobian(q)
Jl1 = rl1.jacobian(q)
Jl2 = rl2.jacobian(q)

# STEP 2: generate expressions for the system space velocities from the jacobians
vb = Jb*dq
vl1 = Jl1*dq
vl2 = Jl2*dq

# STEP 3: generate expressions for the kinetic and potential energy
# mass vectors
Mb = sym.Matrix([[mb,mb,Inb]])
Ml1 = sym.Matrix([[mlt,mlt,Inlt]])
Ml2 = sym.Matrix([[mlb,mlb,Inlb]])

T = 0.5*Mb*sym.matrix_multiply_elementwise(vb,vb) + 0.5*Ml1*sym.matrix_multiply_elementwise(vl1,vl1) + 0.5*Ml2*sym.matrix_multiply_elementwise(vl2,vl2)
T = T[0]
V = mb*g*rb[1] + mlt*g*rl1[1] + mlb*g*rl2[1]


# STEP 4: calculate each term of the Lagrange equation
# term 1
Lg1 = sym.zeros(len(q),1)
for i in range(len(q)):
    dT_ddq = sym.Matrix([sym.diff(T,dq[i])]) # get partial of T in dq_i
    Lg1[i] = dT_ddq.jacobian(q)*dq + dT_ddq.jacobian(dq)*ddq #...then get time derivative of that partial

# term 3
Lg3 = sym.Matrix([T]).jacobian(q).transpose() # partial of T in q

# term 4
Lg4 = sym.Matrix([V]).jacobian(q).transpose() # partial of U in q

# STEP 5: generalized forces

# force vectors for each link
tau_b = sym.Matrix([[0],[0],[-tauh]])
tau_l1 = sym.Matrix([[0],[0],[tauh-tauk]])
tau_l2 = sym.Matrix([[0],[0],[tauk]])

GRF_l2 = sym.Matrix([[GRFx],[GRFy],[0.5*llb*GRFx*sym.cos(thb+thlt+thlb)+0.5*llb*GRFy*sym.sin(thb+thlt+thlb)]])

Q = sym.zeros(len(q),1)
for j in range(len(q)):
    Q[j] = tau_b.transpose()*Jb[:,j]+(tau_l1).transpose()*Jl1[:,j]+(tau_l2+GRF_l2).transpose()*Jl2[:,j]

# AND combine!
EOM = Lg1 - Lg3 + Lg4 - Q

EOMs = sym.zeros(len(q),1)
for j in range(len(q)):
    EOMs[j] = EOM[j].simplify()

# %%
# Position and velocity of monopod foot

pfoot = sym.Matrix([[x + llt*sym.sin(thb + thlt) + llb*sym.sin(thb + thlt + thlb)],
                    [y - llt*sym.cos(thb + thlt) - llb*sym.cos(thb + thlt + thlb)]])

vfoot = pfoot.jacobian(q)*dq

pfoot
# vfoot
# Out:
# ⎡l_{leg1}⋅sin(\theta_{body} + \theta_{legtop}) + l_{leg2}⋅sin(\theta_{body} +
# ⎢
# ⎣-l_{leg1}⋅cos(\theta_{body} + \theta_{legtop}) - l_{leg2}⋅cos(\theta_{body} +
#
# \theta_{legbot} + \theta_{legtop}) + x ⎤
#                                        ⎥
#  \theta_{legbot} + \theta_{legtop}) + y⎦

# %%
import pickle as pkl

data = {"EOMs":EOMs, "pfoot":pfoot, "vfoot":vfoot}

outfile = open('monopod_EOMs','wb')
pkl.dump(data,outfile)
outfile.close()

# %%
infile = open('monopod_EOMs','rb')
data = pkl.load(infile)
infile.close()

EOMs = data['EOMs']
pfoot = data['pfoot']
vfoot = data['vfoot']

# %%
var = [mb, mlt, mlb, lb, llt, llb, Inb, Inlt, Inlb, x, y, thb, thlt, thlb, dx, dy, dthb, dthlt, dthlb]
var_values = [(g, 9.81),(mb,1),(mlt,1),(mlb,1),(lb,1),(llt,1),(llb,1),(Inb,1),(Inlt,1),(Inlb,1)]

# %%
EOM_sub = EOM.subs(var_values)
EOM_sub
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢      -Gₓ⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta_{body} + \th
# ⎢
# ⎢
# ⎢-Gₓ⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta_{body} + \theta_{l
# ⎢
# ⎢
# ⎣
#
#
#
#
#
#
# eta_{legbot} + \theta_{legtop})) - 0.5⋅Gₓ⋅cos(\theta_{body} + \theta_{legbot}
#
#
# egbot} + \theta_{legtop})) - 0.5⋅Gₓ⋅cos(\theta_{body} + \theta_{legbot} + \the
#
#
#
#
#
#
#
#
#
# + \theta_{legtop}) - G_y⋅(sin(\theta_{body} + \theta_{legtop}) + 0.5⋅sin(\thet
#
#
# ta_{legtop}) - G_y⋅(sin(\theta_{body} + \theta_{legtop}) + 0.5⋅sin(\theta_{bod
#
#
#
#
#
#
#
#
#
# a_{body} + \theta_{legbot} + \theta_{legtop})) - 0.5⋅G_y⋅sin(\theta_{body} + \
#
#
# y} + \theta_{legbot} + \theta_{legtop})) - 0.5⋅G_y⋅sin(\theta_{body} + \theta_
#
#
#
#
#
#
#
#
#                                                          ⎛
# theta_{legbot} + \theta_{legtop}) + \ddot{\theta}_{body}⋅⎝0.5⋅(sin(\theta_{bod
#
#                                                    ⎛
# {legbot} + \theta_{legtop}) + \ddot{\theta}_{body}⋅⎝0.5⋅(sin(\theta_{body} + \
#
#
#
#
#
#
#
#
#
# y} + \theta_{legtop}) + 0.5⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legt
#
#
# theta_{legtop}) + 0.5⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}))⋅
#
#
#
#
#
#
#
#
#
# op}))⋅(2⋅sin(\theta_{body} + \theta_{legtop}) + sin(\theta_{body} + \theta_{le
#
#
# (2⋅sin(\theta_{body} + \theta_{legtop}) + sin(\theta_{body} + \theta_{legbot}
#
#
#
#
#
#
#
#
#
# gbot} + \theta_{legtop})) + 0.5⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅co
#
#
# + \theta_{legtop})) + 0.5⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\the
#
#
#
#
#
#
#
#
#
# s(\theta_{body} + \theta_{legbot} + \theta_{legtop}))⋅(2⋅cos(\theta_{body} + \
#
#
# ta_{body} + \theta_{legbot} + \theta_{legtop}))⋅(2⋅cos(\theta_{body} + \theta_
#
#
#
#
#
#
#
#
#
# theta_{legtop}) + cos(\theta_{body} + \theta_{legbot} + \theta_{legtop})) + 0.
#
#
# {legtop}) + cos(\theta_{body} + \theta_{legbot} + \theta_{legtop})) + 0.25⋅sin
#
#
#
#
#
#
#
#
#       2                                            2
# 25⋅sin (\theta_{body} + \theta_{legtop}) + 0.25⋅cos (\theta_{body} + \theta_{l
#
# 2                                            2
#  (\theta_{body} + \theta_{legtop}) + 0.25⋅cos (\theta_{body} + \theta_{legtop}
#
#
#
#
#
#
#
#
#              ⎞
# egtop}) + 3.0⎠ + \ddot{\theta}_{legbot}⋅(0.25⋅(2⋅sin(\theta_{body} + \theta_{l
#
#        ⎞
# ) + 2.0⎠ + \ddot{\theta}_{legbot}⋅(0.25⋅(2⋅sin(\theta_{body} + \theta_{legtop}
#
#
#
#
#
#
#
#
#
# egtop}) + sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}))⋅sin(\theta_{
#
#
# ) + sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}))⋅sin(\theta_{body}
#
#
#
#
#
#
#
#
#
# body} + \theta_{legbot} + \theta_{legtop}) + 0.25⋅(2⋅cos(\theta_{body} + \thet
#
#
# + \theta_{legbot} + \theta_{legtop}) + 0.25⋅(2⋅cos(\theta_{body} + \theta_{leg
#
#
#
#
#
#
#
#
#
# a_{legtop}) + cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}))⋅cos(\the
#
#
# top}) + cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}))⋅cos(\theta_{bo
#
#
#
#
#
#
#
#
#
# ta_{body} + \theta_{legbot} + \theta_{legtop}) + 1.0) + \ddot{\theta}_{legtop}
#
#                                                                          ⎛
# dy} + \theta_{legbot} + \theta_{legtop}) + 1.0) + \ddot{\theta}_{legtop}⋅⎝0.5⋅
#
#
#
#
#
#
#
#
#  ⎛
# ⋅⎝0.5⋅(sin(\theta_{body} + \theta_{legtop}) + 0.5⋅sin(\theta_{body} + \theta_{
#
#
# (sin(\theta_{body} + \theta_{legtop}) + 0.5⋅sin(\theta_{body} + \theta_{legbot
#
#
#
#
#
#
#
#
#
# legbot} + \theta_{legtop}))⋅(2⋅sin(\theta_{body} + \theta_{legtop}) + sin(\the
#
#
# } + \theta_{legtop}))⋅(2⋅sin(\theta_{body} + \theta_{legtop}) + sin(\theta_{bo
#
#
#
#
#
#
#
#
#
# ta_{body} + \theta_{legbot} + \theta_{legtop})) + 0.5⋅(cos(\theta_{body} + \th
#
#
# dy} + \theta_{legbot} + \theta_{legtop})) + 0.5⋅(cos(\theta_{body} + \theta_{l
#
#
#
#
#
#
#
#
#
# eta_{legtop}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}))⋅(2
#
#
# egtop}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}))⋅(2⋅cos(\
#
#
#
#
#
#
#
#
#
# ⋅cos(\theta_{body} + \theta_{legtop}) + cos(\theta_{body} + \theta_{legbot} +
#
#
# theta_{body} + \theta_{legtop}) + cos(\theta_{body} + \theta_{legbot} + \theta
#
#
#
#
#
#
#
#
#                             2                                            2
# \theta_{legtop})) + 0.25⋅sin (\theta_{body} + \theta_{legtop}) + 0.25⋅cos (\th
#
#                       2                                            2
# _{legtop})) + 0.25⋅sin (\theta_{body} + \theta_{legtop}) + 0.25⋅cos (\theta_{b
#
#
#
#
#
#
#
#
#                                    ⎞
# eta_{body} + \theta_{legtop}) + 2.0⎠ + \ddot{x}⋅(1.5⋅cos(\theta_{body} + \thet
#
#                              ⎞
# ody} + \theta_{legtop}) + 2.0⎠ + \ddot{x}⋅(1.5⋅cos(\theta_{body} + \theta_{leg
#
#
#            -1.0⋅Gₓ⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}) - 1.
#
#
#
#
#
#
# a_{legtop}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop})) + \d
#
#
# top}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop})) + \ddot{y}
#
#
# 0⋅G_y⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}) + \ddot{\theta}_{
#
#
#
#
#
#
# dot{y}⋅(1.5⋅sin(\theta_{body} + \theta_{legtop}) + 0.5⋅sin(\theta_{body} + \th
#
#
# ⋅(1.5⋅sin(\theta_{body} + \theta_{legtop}) + 0.5⋅sin(\theta_{body} + \theta_{l
#
#
# body}⋅(0.5⋅(sin(\theta_{body} + \theta_{legtop}) + 0.5⋅sin(\theta_{body} + \th
#
#
#
#
#
#
# eta_{legbot} + \theta_{legtop})) + \dot{\theta}_{body}⋅(0.5⋅(-0.5⋅\dot{\theta}
#
#
# egbot} + \theta_{legtop})) + \dot{\theta}_{body}⋅(0.5⋅(-0.5⋅\dot{\theta}_{body
#
#
# eta_{legbot} + \theta_{legtop}))⋅sin(\theta_{body} + \theta_{legbot} + \theta_
#
#
#
#
#
#
# _{body}⋅sin(\theta_{body} + \theta_{legtop}) - 0.5⋅\dot{\theta}_{legtop}⋅sin(\
#
#
# }⋅sin(\theta_{body} + \theta_{legtop}) - 0.5⋅\dot{\theta}_{legtop}⋅sin(\theta_
#
#
# {legtop}) + 0.5⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta_{body}
#
#
#
#
#
#
# theta_{body} + \theta_{legtop}))⋅cos(\theta_{body} + \theta_{legtop}) + 0.5⋅(0
#
#
# {body} + \theta_{legtop}))⋅cos(\theta_{body} + \theta_{legtop}) + 0.5⋅(0.5⋅\do
#
#
# + \theta_{legbot} + \theta_{legtop}))⋅cos(\theta_{body} + \theta_{legbot} + \t
#
#
#
#
#
#
# .5⋅\dot{\theta}_{body}⋅cos(\theta_{body} + \theta_{legtop}) + 0.5⋅\dot{\theta}
#
#
# t{\theta}_{body}⋅cos(\theta_{body} + \theta_{legtop}) + 0.5⋅\dot{\theta}_{legt
#
#                                                ⎛        2
# heta_{legtop}) + 1.0) + \ddot{\theta}_{legbot}⋅⎝0.25⋅sin (\theta_{body} + \the
#
#
#
#
#
#
# _{legtop}⋅cos(\theta_{body} + \theta_{legtop}))⋅sin(\theta_{body} + \theta_{le
#
#
# op}⋅cos(\theta_{body} + \theta_{legtop}))⋅sin(\theta_{body} + \theta_{legtop})
#
#                                          2
# ta_{legbot} + \theta_{legtop}) + 0.25⋅cos (\theta_{body} + \theta_{legbot} + \
#
#
#
#
#
#
# gtop}) + 0.5⋅(-2⋅sin(\theta_{body} + \theta_{legtop}) - sin(\theta_{body} + \t
#
#
#  + 0.5⋅(-2⋅sin(\theta_{body} + \theta_{legtop}) - sin(\theta_{body} + \theta_{
#
#                      ⎞
# theta_{legtop}) + 1.0⎠ + \ddot{\theta}_{legtop}⋅(0.5⋅(sin(\theta_{body} + \the
#
#
#
#
#
#
# heta_{legbot} + \theta_{legtop}))⋅(\dot{\theta}_{body}⋅(cos(\theta_{body} + \t
#
#
# legbot} + \theta_{legtop}))⋅(\dot{\theta}_{body}⋅(cos(\theta_{body} + \theta_{
#
#
# ta_{legtop}) + 0.5⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}))⋅sin
#
#
#
#
#
#
# heta_{legtop}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop})) +
#
#
# legtop}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop})) + 0.5⋅\
#
#
# (\theta_{body} + \theta_{legbot} + \theta_{legtop}) + 0.5⋅(cos(\theta_{body} +
#
#
#
#
#
#
#  0.5⋅\dot{\theta}_{legbot}⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legto
#
#
# dot{\theta}_{legbot}⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}) +
#
#
#  \theta_{legtop}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop})
#
#
#
#
#
#
# p}) + \dot{\theta}_{legtop}⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\t
#
#
# \dot{\theta}_{legtop}⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta_{
#
#
# )⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}) + 1.0) + 0.5⋅\ddot{x}
#
#
#
#
#
#
# heta_{body} + \theta_{legbot} + \theta_{legtop})) + \dot{x}) + 0.5⋅(2⋅sin(\the
#
#
# body} + \theta_{legbot} + \theta_{legtop})) + \dot{x}) + 0.5⋅(2⋅sin(\theta_{bo
#
#
# ⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}) + 0.5⋅\ddot{y}⋅sin(\th
#
#
#
#
#
#
# ta_{body} + \theta_{legtop}) + sin(\theta_{body} + \theta_{legbot} + \theta_{l
#
#
# dy} + \theta_{legtop}) + sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}
#
#
# eta_{body} + \theta_{legbot} + \theta_{legtop}) + \dot{\theta}_{body}⋅(0.5⋅(\d
#
#
#
#
#
#
# egtop}))⋅(\dot{\theta}_{body}⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(
#
#
# ))⋅(\dot{\theta}_{body}⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta
#
#
# ot{\theta}_{body}⋅(-sin(\theta_{body} + \theta_{legtop}) - 0.5⋅sin(\theta_{bod
#
#
#
#
#
#
# \theta_{body} + \theta_{legbot} + \theta_{legtop})) + 0.5⋅\dot{\theta}_{legbot
#
#
# _{body} + \theta_{legbot} + \theta_{legtop})) + 0.5⋅\dot{\theta}_{legbot}⋅cos(
#
#
# y} + \theta_{legbot} + \theta_{legtop})) - 0.5⋅\dot{\theta}_{legbot}⋅sin(\thet
#
#
#
#
#
#
# }⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}) + \dot{\theta}_{legto
#
#
# \theta_{body} + \theta_{legbot} + \theta_{legtop}) + \dot{\theta}_{legtop}⋅(co
#
#
# a_{body} + \theta_{legbot} + \theta_{legtop}) + \dot{\theta}_{legtop}⋅(-sin(\t
#
#
#
#
#
#
# p}⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta_{body} + \theta_{leg
#
#
# s(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} +
#
#
# heta_{body} + \theta_{legtop}) - 0.5⋅sin(\theta_{body} + \theta_{legbot} + \th
#
#
#
#
#
#
# bot} + \theta_{legtop}))) + 0.5⋅(2⋅cos(\theta_{body} + \theta_{legtop}) + cos(
#
#
#  \theta_{legtop}))) + 0.5⋅(2⋅cos(\theta_{body} + \theta_{legtop}) + cos(\theta
#
#
# eta_{legtop})))⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}) + 0.5⋅(
#
#
#
#
#
#
# \theta_{body} + \theta_{legbot} + \theta_{legtop}))⋅(\dot{\theta}_{body}⋅(-sin
#
#
# _{body} + \theta_{legbot} + \theta_{legtop}))⋅(\dot{\theta}_{body}⋅(-sin(\thet
#
#
# \dot{\theta}_{body}⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta_{bo
#
#
#
#
#
#
# (\theta_{body} + \theta_{legtop}) - 0.5⋅sin(\theta_{body} + \theta_{legbot} +
#
#
# a_{body} + \theta_{legtop}) - 0.5⋅sin(\theta_{body} + \theta_{legbot} + \theta
#
#
# dy} + \theta_{legbot} + \theta_{legtop})) + 0.5⋅\dot{\theta}_{legbot}⋅cos(\the
#
#
#
#
#
#
# \theta_{legtop})) - 0.5⋅\dot{\theta}_{legbot}⋅sin(\theta_{body} + \theta_{legb
#
#
# _{legtop})) - 0.5⋅\dot{\theta}_{legbot}⋅sin(\theta_{body} + \theta_{legbot} +
#
#
# ta_{body} + \theta_{legbot} + \theta_{legtop}) + \dot{\theta}_{legtop}⋅(cos(\t
#
#
#
#
#
#
# ot} + \theta_{legtop}) + \dot{\theta}_{legtop}⋅(-sin(\theta_{body} + \theta_{l
#
#
# \theta_{legtop}) + \dot{\theta}_{legtop}⋅(-sin(\theta_{body} + \theta_{legtop}
#
#
# heta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} + \th
#
#
#
#
#
#
# egtop}) - 0.5⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}))) + 0.5⋅(
#
#
# ) - 0.5⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}))) + 0.5⋅(2⋅cos(
#
#
# eta_{legtop})))⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}) + 0.5⋅(
#
#
#
#
#
#
# 2⋅cos(\theta_{body} + \theta_{legtop}) + cos(\theta_{body} + \theta_{legbot} +
#
#
# \theta_{body} + \theta_{legtop}) + cos(\theta_{body} + \theta_{legbot} + \thet
#
#
# \dot{\theta}_{body}⋅(sin(\theta_{body} + \theta_{legtop}) + 0.5⋅sin(\theta_{bo
#
#
#
#
#
#
#  \theta_{legtop}))⋅(\dot{\theta}_{body}⋅(sin(\theta_{body} + \theta_{legtop})
#
#
# a_{legtop}))⋅(\dot{\theta}_{body}⋅(sin(\theta_{body} + \theta_{legtop}) + 0.5⋅
#
#
# dy} + \theta_{legbot} + \theta_{legtop})) + 0.5⋅\dot{\theta}_{legbot}⋅sin(\the
#
#
#
#
#
#
# + 0.5⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop})) + 0.5⋅\dot{\thet
#
#
# sin(\theta_{body} + \theta_{legbot} + \theta_{legtop})) + 0.5⋅\dot{\theta}_{le
#
#
# ta_{body} + \theta_{legbot} + \theta_{legtop}) + \dot{\theta}_{legtop}⋅(sin(\t
#
#
#
#
#
#
# a}_{legbot}⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}) + \dot{\the
# ...
#
# ot} + \theta_{legtop})) - 1.0⋅\dot{\theta}_{legbot}⋅sin(\theta_{body} + \theta
#
#
#
#
#
#
#
#
#
# t} + \theta_{legtop}) + 2⋅\dot{\theta}_{legtop}⋅(-sin(\theta_{body} + \theta_{
#
#
# _{legbot} + \theta_{legtop}) + 2⋅\dot{\theta}_{legtop}⋅(-sin(\theta_{body} + \
#
#
#
#
#
#
#
#
#
# legtop}) - 0.5⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop})))⋅(\dot{
#
#
# theta_{legtop}) - 0.5⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop})))
#
#
#
#
#
#
#
#
#
# \theta}_{body}⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta_{body} +
#
#
# ⋅(\dot{\theta}_{body}⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta_{
#
#
#
#
#
#
#
#
#
#  \theta_{legbot} + \theta_{legtop})) + 0.5⋅\dot{\theta}_{legbot}⋅cos(\theta_{b
#
#
# body} + \theta_{legbot} + \theta_{legtop})) + 0.5⋅\dot{\theta}_{legbot}⋅cos(\t
#
#
#
#
#
#
#
#
#
# ody} + \theta_{legbot} + \theta_{legtop}) + \dot{\theta}_{legtop}⋅(cos(\theta_
#
#
# heta_{body} + \theta_{legbot} + \theta_{legtop}) + \dot{\theta}_{legtop}⋅(cos(
#
#
#
#
#
#
#
#
#
# {body} + \theta_{legtop}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} + \theta_{
#
#
# \theta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} + \
#
#
#
#
#
#
#
#
#
# legtop})) + \dot{x}) - 0.5⋅(2⋅\dot{\theta}_{body}⋅(cos(\theta_{body} + \theta_
#
#
# theta_{legtop})) + \dot{x}) - 0.5⋅(2⋅\dot{\theta}_{body}⋅(cos(\theta_{body} +
#
#
#
#
#
#
#
#
#
# {legtop}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop})) + \dot
#
#
# \theta_{legtop}) + 0.5⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}))
#
#
#
#
#
#
#
#
#
# {\theta}_{legbot}⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}) + 2⋅\
#
#
#  + \dot{\theta}_{legbot}⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}
#
#
#
#
#
#
#
#
#
# dot{\theta}_{legtop}⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\theta_{b
#
#
# ) + 2⋅\dot{\theta}_{legtop}⋅(cos(\theta_{body} + \theta_{legtop}) + 0.5⋅cos(\t
#
#
#
#
#
#
#
#
#
# ody} + \theta_{legbot} + \theta_{legtop})))⋅(\dot{\theta}_{body}⋅(sin(\theta_{
#
#
# heta_{body} + \theta_{legbot} + \theta_{legtop})))⋅(\dot{\theta}_{body}⋅(sin(\
#
#
#
#
#
#
#
#
#
# body} + \theta_{legtop}) + 0.5⋅sin(\theta_{body} + \theta_{legbot} + \theta_{l
#
#
# theta_{body} + \theta_{legtop}) + 0.5⋅sin(\theta_{body} + \theta_{legbot} + \t
#
#
#
#
#
#
#
#
#
# egtop})) + 0.5⋅\dot{\theta}_{legbot}⋅sin(\theta_{body} + \theta_{legbot} + \th
#
#
# heta_{legtop})) + 0.5⋅\dot{\theta}_{legbot}⋅sin(\theta_{body} + \theta_{legbot
#
#
#
#
#
#
#
#
#
# eta_{legtop}) + \dot{\theta}_{legtop}⋅(sin(\theta_{body} + \theta_{legtop}) +
#
#
# } + \theta_{legtop}) + \dot{\theta}_{legtop}⋅(sin(\theta_{body} + \theta_{legt
#
#
#
#
#
#
#
#
#
# 0.5⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop})) + \dot{y}) + 14.71
#
#
# op}) + 0.5⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop})) + \dot{y})
#
#
#
#
#
#
#
#
#
# 5⋅sin(\theta_{body} + \theta_{legtop}) + 4.905⋅sin(\theta_{body} + \theta_{leg
#
#
# + 14.715⋅sin(\theta_{body} + \theta_{legtop}) + 4.905⋅sin(\theta_{body} + \the
#
#
#
#
#                               ⎤
#                               ⎥
#                               ⎥
#                               ⎥
#                               ⎥
# bot} + \theta_{legtop})       ⎥
#                               ⎥
#                               ⎥
# ta_{legbot} + \theta_{legtop})⎥
#                               ⎥
#                               ⎥
#                               ⎦

# %%
EOM_sub.evalf()
# Out:
# ⎡                             -1.11921650312094⋅\ddot{\theta}_{body} - 0.49499
# ⎢
# ⎢                         1.43450614426846⋅\ddot{\theta}_{body} + 0.0705600040
# ⎢
# ⎢5.04030230586814⋅\ddot{\theta}_{body} + 1.52015115293407⋅\ddot{\theta}_{legbo
# ⎢
# ⎢4.04030230586814⋅\ddot{\theta}_{body} + 1.52015115293407⋅\ddot{\theta}_{legbo
# ⎢
# ⎣   1.52015115293407⋅\ddot{\theta}_{body} + 1.25⋅\ddot{\theta}_{legbot} + 1.52
#
# 6248300223⋅\ddot{\theta}_{legbot} - 1.11921650312094⋅\ddot{\theta}_{legtop} +
#
# 299336⋅\ddot{\theta}_{legbot} + 1.43450614426846⋅\ddot{\theta}_{legtop} + 3.0⋅
#
# t} + 4.04030230586814⋅\ddot{\theta}_{legtop} - 1.11921650312094⋅\ddot{x} + 1.4
#
# t} + 4.04030230586814⋅\ddot{\theta}_{legtop} - 1.11921650312094⋅\ddot{x} + 1.4
#
# 015115293407⋅\ddot{\theta}_{legtop} - 0.494996248300223⋅\ddot{x} + 0.070560004
#
# 3.0⋅\ddot{x} - 7.09082459722349                              ⎤
#                                                              ⎥
# \ddot{y} + 3.0⋅g - 7.95184725398486                          ⎥
#                                                              ⎥
# 3450614426846⋅\ddot{y} + 1.43450614426846⋅g - 1.7479555637577⎥
#                                                              ⎥
# 3450614426846⋅\ddot{y} + 1.43450614426846⋅g - 2.7479555637577⎥
#                                                              ⎥
# 0299336⋅\ddot{y} + 0.0705600040299336⋅g + 1.53181445815637   ⎦

# %%
EOM_solve = sym.solve(EOM_sub, ddq)

# %%
func_map = {'sin':sin, 'cos':cos} 

sym_list = [g,mb,mlt,mlb,lb,llt,llb,Inb,Inlt,Inlb,
            x,y,thb,thlt,thlb,
            dx,dy,dthb,dthlt,dthlb,
            ddx,ddy,ddthb,ddthlt,ddthlb,
            tauh,tauk,GRFx,GRFy]
            
lambEOM_xb = sym.lambdify(sym_list,EOMs[0],modules = [func_map])
lambEOM_yb = sym.lambdify(sym_list,EOMs[1],modules = [func_map])
lambEOM_thb = sym.lambdify(sym_list,EOMs[2],modules = [func_map])
lambEOM_thlt = sym.lambdify(sym_list,EOMs[3],modules = [func_map])
lambEOM_thlb = sym.lambdify(sym_list,EOMs[4],modules = [func_map])

# %%
def update(q, dq):
    for i in range(num_vars):
        ddq[i] = EOM_lambdified[i](q, dq)
