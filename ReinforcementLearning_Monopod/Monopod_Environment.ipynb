# %% [markdown]
# # Create a Monopod Environment for RL

# %%
import sys
sys.executable

sys.path
# Out:
# ['C:\\Users\\Nick\\Google Drive\\PythonPrograms\\machine_learning_projects\\ReinforcementLearning_Monopod',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda3\\envs\\envCartPole\\python37.zip',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda3\\envs\\envCartPole\\DLLs',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda3\\envs\\envCartPole\\lib',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda3\\envs\\envCartPole',
#  '',
#  'C:\\Users\\Nick\\AppData\\Roaming\\Python\\Python37\\site-packages',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda3\\envs\\envCartPole\\lib\\site-packages',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda3\\envs\\envCartPole\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Nick\\.ipython']

# %%
# %reset
# DERIVE THE EOMs SYMBOLICALLY ----------------------------------------------------------------------------------------------

# import libraries
import sympy as sym
import numpy as np

sym.init_printing()
from IPython.display import display #for pretty printing

# create symbolic variables

# system parameters
g = sym.symbols('g')
mb,ml1,ml2 = sym.symbols(['m_{body}','m_{leg1}','m_{leg2}']) # mass
lb,ll1,ll2 = sym.symbols(['l_{body}','l_{leg1}','l_{leg2}']) # length
Inb,Inl1,Inl2 = sym.symbols(['I_{body}','I_{leg1}','I_{leg2}']) # moment of intertia

# generalized coordinates
x,y,thb,thlt,thlb = sym.symbols(['x','y','\\theta_{body}','\\theta_{legtop}','\\theta_{legbot}']) 
dx,dy,dthb,dthlt,dthlb = sym.symbols(['\dot{x}','\dot{y}','\dot{\\theta}_{body}','\dot{\\theta}_{legtop}','\dot{\\theta}_{legbot}']) 
ddx,ddy,ddthb,ddthlt,ddthlb = sym.symbols(['\ddot{x}','\ddot{y}','\ddot{\\theta}_{body}','\ddot{\\theta}_{legtop}','\ddot{\\theta}_{legbot}']) 

q = sym.Matrix([[x],[y],[thb],[thlt],[thlb]])
dq = sym.Matrix([[dx],[dy],[dthb],[dthlt],[dthlb]])
ddq = sym.Matrix([[ddx],[ddy],[ddthb],[ddthlt],[ddthlb]])

# forces
# total joint action = actuator + rebound, but that will be dealt with elsewhere
tauh,tauk,GRFx,GRFy = sym.symbols(['\\tau_{hip}','\\tau_{knee}','G_x','G_y']) 

# STEP 1: position vectors ri = [x,y,theta] (world frame)
rb = sym.Matrix([[x],
                [y],
                [thb]])

rl1 = sym.Matrix([[x + 0.5*ll1*sym.sin(thb + thlt)],
                [y - 0.5*ll1*sym.cos(thb + thlt)],
                [thb + thlt]])

rl2 = sym.Matrix([[x + ll1*sym.sin(thb + thlt)+0.5*ll2*sym.sin(thb + thlt + thlb)],
                [y - ll1*sym.cos(thb + thlt) - 0.5*ll2*sym.cos(thb + thlt + thlb)],
                [thb + thlt + thlb]])

# the Jacobians
Jb = rb.jacobian(q)
Jl1 = rl1.jacobian(q)
Jl2 = rl2.jacobian(q)

# STEP 2: generate expressions for the system space velocities from the jacobians
vb = Jb*dq
vl1 = Jl1*dq
vl2 = Jl2*dq

# STEP 3: generate expressions for the kinetic and potential energy
# mass vectors
Mb = sym.Matrix([[mb,mb,Inb]])
Ml1 = sym.Matrix([[ml1,ml1,Inl1]])
Ml2 = sym.Matrix([[ml2,ml2,Inl2]])

T = 0.5*Mb*sym.matrix_multiply_elementwise(vb,vb) + 0.5*Ml1*sym.matrix_multiply_elementwise(vl1,vl1) + 0.5*Ml2*sym.matrix_multiply_elementwise(vl2,vl2)
T = T[0]
V = mb*g*rb[1] + ml1*g*rl1[1] + ml2*g*rl2[1]


# STEP 4: calculate each term of the Lagrange equation
# term 1
Lg1 = sym.zeros(len(q),1)
for i in range(len(q)):
    dT_ddq = sym.Matrix([sym.diff(T,dq[i])]) # get partial of T in dq_i
    Lg1[i] = dT_ddq.jacobian(q)*dq + dT_ddq.jacobian(dq)*ddq #...then get time derivative of that partial

# term 3
Lg3 = sym.Matrix([T]).jacobian(q).transpose() # partial of T in q

# term 4
Lg4 = sym.Matrix([V]).jacobian(q).transpose() # partial of U in q

# STEP 5: generalized forces

# force vectors for each link
tau_b = sym.Matrix([[0],[0],[-tauh]])
tau_l1 = sym.Matrix([[0],[0],[tauh-tauk]])
tau_l2 = sym.Matrix([[0],[0],[tauk]])

GRF_l2 = sym.Matrix([[GRFx],[GRFy],[0.5*ll2*GRFx*sym.cos(thb+thlt+thlb)+0.5*ll2*GRFy*sym.sin(thb+thlt+thlb)]])

Q = sym.zeros(len(q),1)
for j in range(len(q)):
    Q[j] = tau_b.transpose()*Jb[:,j]+(tau_l1).transpose()*Jl1[:,j]+(tau_l2+GRF_l2).transpose()*Jl2[:,j]

# AND combine!
EOM = Lg1 - Lg3 + Lg4 - Q

EOMs = sym.zeros(len(q),1)
for j in range(len(q)):
    EOMs[j] = EOM[j].simplify()

# %%
EOMs
# Out:
# ⎡
# ⎢                           -1.0⋅Gₓ + 0.5⋅\ddot{\theta}_{body}⋅l_{leg1}⋅m_{leg
# ⎢
# ⎢
# ⎢ -1.0⋅G_y + 0.5⋅\ddot{\theta}_{body}⋅l_{leg1}⋅m_{leg1}⋅sin(\theta_{body} + \t
# ⎢
# ⎢
# ⎢-1.0⋅Gₓ⋅l_{leg1}⋅cos(\theta_{body} + \theta_{legtop}) - 1.0⋅Gₓ⋅l_{leg2}⋅cos(\
# ⎢
# ⎢
# ⎢         -1.0⋅Gₓ⋅l_{leg1}⋅cos(\theta_{body} + \theta_{legtop}) - 1.0⋅Gₓ⋅l_{le
# ⎢
# ⎢
# ⎣
#
#
# 1}⋅cos(\theta_{body} + \theta_{legtop}) + 1.0⋅\ddot{\theta}_{body}⋅l_{leg1}⋅m_
#
#
# heta_{legtop}) + 1.0⋅\ddot{\theta}_{body}⋅l_{leg1}⋅m_{leg2}⋅sin(\theta_{body}
#
#
# theta_{body} + \theta_{legbot} + \theta_{legtop}) - 1.0⋅G_y⋅l_{leg1}⋅sin(\thet
#
#
# g2}⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}) - 1.0⋅G_y⋅l_{leg1}⋅
#
#
#
#
#
# {leg2}⋅cos(\theta_{body} + \theta_{legtop}) + 0.5⋅\ddot{\theta}_{body}⋅l_{leg2
#
#
# + \theta_{legtop}) + 0.5⋅\ddot{\theta}_{body}⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{bo
#
#
# a_{body} + \theta_{legtop}) - 1.0⋅G_y⋅l_{leg2}⋅sin(\theta_{body} + \theta_{leg
#
#
# sin(\theta_{body} + \theta_{legtop}) - 1.0⋅G_y⋅l_{leg2}⋅sin(\theta_{body} + \t
#
#
#
#
#
# }⋅m_{leg2}⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}) + 0.5⋅\ddot{
#
#
# dy} + \theta_{legbot} + \theta_{legtop}) + 0.5⋅\ddot{\theta}_{legbot}⋅l_{leg2}
#
#
# bot} + \theta_{legtop}) + 1.0⋅I_{body}⋅\ddot{\theta}_{body} + 1.0⋅I_{leg1}⋅\dd
#
#
# heta_{legbot} + \theta_{legtop}) + 1.0⋅I_{leg1}⋅\ddot{\theta}_{body} + 1.0⋅I_{
#
#
#
#
#
# \theta}_{legbot}⋅l_{leg2}⋅m_{leg2}⋅cos(\theta_{body} + \theta_{legbot} + \thet
#
#
# ⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}) + 0.5⋅\ddot{\
#
#
# ot{\theta}_{body} + 1.0⋅I_{leg1}⋅\ddot{\theta}_{legtop} + 1.0⋅I_{leg2}⋅\ddot{\
#
#
# leg1}⋅\ddot{\theta}_{legtop} + 1.0⋅I_{leg2}⋅\ddot{\theta}_{body} + 1.0⋅I_{leg2
#
#
#
#
#
# a_{legtop}) + 0.5⋅\ddot{\theta}_{legtop}⋅l_{leg1}⋅m_{leg1}⋅cos(\theta_{body} +
#
#
# theta}_{legtop}⋅l_{leg1}⋅m_{leg1}⋅sin(\theta_{body} + \theta_{legtop}) + 1.0⋅\
#
#
# theta}_{body} + 1.0⋅I_{leg2}⋅\ddot{\theta}_{legbot} + 1.0⋅I_{leg2}⋅\ddot{\thet
#
#
# }⋅\ddot{\theta}_{legbot} + 1.0⋅I_{leg2}⋅\ddot{\theta}_{legtop} + 0.25⋅\ddot{\t
#
#
#                                                             -1.0⋅Gₓ⋅l_{leg2}⋅c
#
#
#  \theta_{legtop}) + 1.0⋅\ddot{\theta}_{legtop}⋅l_{leg1}⋅m_{leg2}⋅cos(\theta_{b
#
#
# ddot{\theta}_{legtop}⋅l_{leg1}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legtop}) +
#
#                                                 2
# a}_{legtop} + 0.25⋅\ddot{\theta}_{body}⋅l_{leg1} ⋅m_{leg1} + 1.0⋅\ddot{\theta}
#
#                      2                                             2
# heta}_{body}⋅l_{leg1} ⋅m_{leg1} + 1.0⋅\ddot{\theta}_{body}⋅l_{leg1} ⋅m_{leg2}
#
#
# os(\theta_{body} + \theta_{legbot} + \theta_{legtop}) - 1.0⋅G_y⋅l_{leg2}⋅sin(\
#
#
# ody} + \theta_{legtop}) + 0.5⋅\ddot{\theta}_{legtop}⋅l_{leg2}⋅m_{leg2}⋅cos(\th
#
#
#  0.5⋅\ddot{\theta}_{legtop}⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legb
#
#                 2
# _{body}⋅l_{leg1} ⋅m_{leg2} + 1.0⋅\ddot{\theta}_{body}⋅l_{leg1}⋅l_{leg2}⋅m_{leg
#
#
# + 1.0⋅\ddot{\theta}_{body}⋅l_{leg1}⋅l_{leg2}⋅m_{leg2}⋅cos(\theta_{legbot}) + 0
#
#
# theta_{body} + \theta_{legbot} + \theta_{legtop}) + 1.0⋅I_{leg2}⋅\ddot{\theta}
#
#
# eta_{body} + \theta_{legbot} + \theta_{legtop}) + 1.0⋅\ddot{x}⋅m_{body} + 1.0⋅
#
#
# ot} + \theta_{legtop}) + 1.0⋅\ddot{y}⋅m_{body} + 1.0⋅\ddot{y}⋅m_{leg1} + 1.0⋅\
#
#                                                             2
# 2}⋅cos(\theta_{legbot}) + 0.25⋅\ddot{\theta}_{body}⋅l_{leg2} ⋅m_{leg2} + 0.5⋅\
#
#                                  2
# .25⋅\ddot{\theta}_{body}⋅l_{leg2} ⋅m_{leg2} + 0.5⋅\ddot{\theta}_{legbot}⋅l_{le
#
#
# _{body} + 1.0⋅I_{leg2}⋅\ddot{\theta}_{legbot} + 1.0⋅I_{leg2}⋅\ddot{\theta}_{le
#
#                                                                    2
# \ddot{x}⋅m_{leg1} + 1.0⋅\ddot{x}⋅m_{leg2} - 0.5⋅\dot{\theta}_{body} ⋅l_{leg1}⋅
#
#                                           2
# ddot{y}⋅m_{leg2} + 0.5⋅\dot{\theta}_{body} ⋅l_{leg1}⋅m_{leg1}⋅cos(\theta_{body
#
#
# ddot{\theta}_{legbot}⋅l_{leg1}⋅l_{leg2}⋅m_{leg2}⋅cos(\theta_{legbot}) + 0.25⋅\
#
#
# g1}⋅l_{leg2}⋅m_{leg2}⋅cos(\theta_{legbot}) + 0.25⋅\ddot{\theta}_{legbot}⋅l_{le
#
#
# gtop} + 0.5⋅\ddot{\theta}_{body}⋅l_{leg1}⋅l_{leg2}⋅m_{leg2}⋅cos(\theta_{legbot
#
#                                                                        2
# m_{leg1}⋅sin(\theta_{body} + \theta_{legtop}) - 1.0⋅\dot{\theta}_{body} ⋅l_{le
#
#                                               2
# } + \theta_{legtop}) + 1.0⋅\dot{\theta}_{body} ⋅l_{leg1}⋅m_{leg2}⋅cos(\theta_{
#
#                               2
# ddot{\theta}_{legbot}⋅l_{leg2} ⋅m_{leg2} + 0.25⋅\ddot{\theta}_{legtop}⋅l_{leg1
#
#    2                                                2
# g2} ⋅m_{leg2} + 0.25⋅\ddot{\theta}_{legtop}⋅l_{leg1} ⋅m_{leg1} + 1.0⋅\ddot{\th
#
#                                        2
# }) + 0.25⋅\ddot{\theta}_{body}⋅l_{leg2} ⋅m_{leg2} + 0.25⋅\ddot{\theta}_{legbot
#
#                                                                            2
# g1}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legtop}) - 0.5⋅\dot{\theta}_{body} ⋅l
#
#                                                   2
# body} + \theta_{legtop}) + 0.5⋅\dot{\theta}_{body} ⋅l_{leg2}⋅m_{leg2}⋅cos(\the
#
#  2                                               2
# } ⋅m_{leg1} + 1.0⋅\ddot{\theta}_{legtop}⋅l_{leg1} ⋅m_{leg2} + 1.0⋅\ddot{\theta
#
#                       2
# eta}_{legtop}⋅l_{leg1} ⋅m_{leg2} + 1.0⋅\ddot{\theta}_{legtop}⋅l_{leg1}⋅l_{leg2
#
#           2
# }⋅l_{leg2} ⋅m_{leg2} + 0.5⋅\ddot{\theta}_{legtop}⋅l_{leg1}⋅l_{leg2}⋅m_{leg2}⋅c
#
#
# _{leg2}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}) - 1.0⋅
#
#
# ta_{body} + \theta_{legbot} + \theta_{legtop}) + 1.0⋅\dot{\theta}_{body}⋅\dot{
#
#
# }_{legtop}⋅l_{leg1}⋅l_{leg2}⋅m_{leg2}⋅cos(\theta_{legbot}) + 0.25⋅\ddot{\theta
#
#                                                                       2
# }⋅m_{leg2}⋅cos(\theta_{legbot}) + 0.25⋅\ddot{\theta}_{legtop}⋅l_{leg2} ⋅m_{leg
#
#                                                           2
# os(\theta_{legbot}) + 0.25⋅\ddot{\theta}_{legtop}⋅l_{leg2} ⋅m_{leg2} + 0.5⋅\dd
#
#
# \dot{\theta}_{body}⋅\dot{\theta}_{legbot}⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{body}
#
#
# \theta}_{legbot}⋅l_{leg2}⋅m_{leg2}⋅cos(\theta_{body} + \theta_{legbot} + \thet
#
#                    2
# }_{legtop}⋅l_{leg2} ⋅m_{leg2} + 0.5⋅\ddot{x}⋅l_{leg1}⋅m_{leg1}⋅cos(\theta_{bod
#
#
# 2} + 0.5⋅\ddot{x}⋅l_{leg1}⋅m_{leg1}⋅cos(\theta_{body} + \theta_{legtop}) + 1.0
#
#
# ot{x}⋅l_{leg2}⋅m_{leg2}⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop})
#
#
# + \theta_{legbot} + \theta_{legtop}) - 1.0⋅\dot{\theta}_{body}⋅\dot{\theta}_{l
#
#
# a_{legtop}) + 1.0⋅\dot{\theta}_{body}⋅\dot{\theta}_{legtop}⋅l_{leg1}⋅m_{leg1}⋅
#
#
# y} + \theta_{legtop}) + 1.0⋅\ddot{x}⋅l_{leg1}⋅m_{leg2}⋅cos(\theta_{body} + \th
#
#
# ⋅\ddot{x}⋅l_{leg1}⋅m_{leg2}⋅cos(\theta_{body} + \theta_{legtop}) + 0.5⋅\ddot{x
#
#
#  + 0.5⋅\ddot{y}⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legbot} + \theta
#
#
# egtop}⋅l_{leg1}⋅m_{leg1}⋅sin(\theta_{body} + \theta_{legtop}) - 2.0⋅\dot{\thet
#
#
# cos(\theta_{body} + \theta_{legtop}) + 2.0⋅\dot{\theta}_{body}⋅\dot{\theta}_{l
#
#
# eta_{legtop}) + 0.5⋅\ddot{x}⋅l_{leg2}⋅m_{leg2}⋅cos(\theta_{body} + \theta_{leg
#
#
# }⋅l_{leg2}⋅m_{leg2}⋅cos(\theta_{body} + \theta_{legbot} + \theta_{legtop}) + 0
#
#                                     2
# _{legtop}) + 0.5⋅\dot{\theta}_{body} ⋅l_{leg1}⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{l
#
#
# a}_{body}⋅\dot{\theta}_{legtop}⋅l_{leg1}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{
#
#
# egtop}⋅l_{leg1}⋅m_{leg2}⋅cos(\theta_{body} + \theta_{legtop}) + 1.0⋅\dot{\thet
#
#
# bot} + \theta_{legtop}) + 0.5⋅\ddot{y}⋅l_{leg1}⋅m_{leg1}⋅sin(\theta_{body} + \
#
#
# .5⋅\ddot{y}⋅l_{leg1}⋅m_{leg1}⋅sin(\theta_{body} + \theta_{legtop}) + 1.0⋅\ddot
#
#
# egbot}) + 1.0⋅\dot{\theta}_{body}⋅\dot{\theta}_{legtop}⋅l_{leg1}⋅l_{leg2}⋅m_{l
#
#
# legtop}) - 1.0⋅\dot{\theta}_{body}⋅\dot{\theta}_{legtop}⋅l_{leg2}⋅m_{leg2}⋅sin
#
#
# a}_{body}⋅\dot{\theta}_{legtop}⋅l_{leg2}⋅m_{leg2}⋅cos(\theta_{body} + \theta_{
#
#
# theta_{legtop}) + 1.0⋅\ddot{y}⋅l_{leg1}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{l
#
#
# {y}⋅l_{leg1}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legtop}) + 0.5⋅\ddot{y}⋅l_{l
#
#                                                      2
# eg2}⋅sin(\theta_{legbot}) + 0.5⋅\dot{\theta}_{legtop} ⋅l_{leg1}⋅l_{leg2}⋅m_{le
#
#
# (\theta_{body} + \theta_{legbot} + \theta_{legtop}) - 0.5⋅\dot{\theta}_{legbot
#
#                                                       2
# legbot} + \theta_{legtop}) + 0.5⋅\dot{\theta}_{legbot} ⋅l_{leg2}⋅m_{leg2}⋅cos(
#
#
# egtop}) + 0.5⋅\ddot{y}⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legbot} +
#
#
# eg2}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}) - 1.0⋅\do
#
#
# g2}⋅sin(\theta_{legbot}) - 1.0⋅\tau_{knee} + 0.5⋅g⋅l_{leg2}⋅m_{leg2}⋅sin(\thet
#
#  2
# } ⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop}) -
#
#
# \theta_{body} + \theta_{legbot} + \theta_{legtop}) + 1.0⋅\dot{\theta}_{legbot}
#
#
#  \theta_{legtop}) - 1.0⋅\dot{\theta}_{body}⋅\dot{\theta}_{legbot}⋅l_{leg1}⋅l_{
#
#
# t{\theta}_{body}⋅\dot{\theta}_{legbot}⋅l_{leg1}⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{
#
#
# a_{body} + \theta_{legbot} + \theta_{legtop})
#
#
# 1.0⋅\dot{\theta}_{legbot}⋅\dot{\theta}_{legtop}⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{
#
#
# ⋅\dot{\theta}_{legtop}⋅l_{leg2}⋅m_{leg2}⋅cos(\theta_{body} + \theta_{legbot} +
#
#                                                                2
# leg2}⋅m_{leg2}⋅sin(\theta_{legbot}) - 0.5⋅\dot{\theta}_{legbot} ⋅l_{leg1}⋅l_{l
#
#                                     2
# legbot}) - 0.5⋅\dot{\theta}_{legbot} ⋅l_{leg1}⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{l
#
#
#
#
#                                                                       2
# body} + \theta_{legbot} + \theta_{legtop}) - 0.5⋅\dot{\theta}_{legtop} ⋅l_{leg
#
#                                              2
#  \theta_{legtop}) + 0.5⋅\dot{\theta}_{legtop} ⋅l_{leg1}⋅m_{leg1}⋅cos(\theta_{b
#
#
# eg2}⋅m_{leg2}⋅sin(\theta_{legbot}) - 1.0⋅\dot{\theta}_{legbot}⋅\dot{\theta}_{l
#
#
# egbot}) - 1.0⋅\dot{\theta}_{legbot}⋅\dot{\theta}_{legtop}⋅l_{leg1}⋅l_{leg2}⋅m_
#
#
#
#
#                                                                             2
# 1}⋅m_{leg1}⋅sin(\theta_{body} + \theta_{legtop}) - 1.0⋅\dot{\theta}_{legtop} ⋅
#
#                                                    2
# ody} + \theta_{legtop}) + 1.0⋅\dot{\theta}_{legtop} ⋅l_{leg1}⋅m_{leg2}⋅cos(\th
#
#
# egtop}⋅l_{leg1}⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{legbot}) + 0.5⋅g⋅l_{leg1}⋅m_{leg
#
#
# {leg2}⋅sin(\theta_{legbot}) - 1.0⋅\tau_{hip} + 0.5⋅g⋅l_{leg1}⋅m_{leg1}⋅sin(\th
#
#
#
#
#
# l_{leg1}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legtop}) - 0.5⋅\dot{\theta}_{leg
#
#                                                          2
# eta_{body} + \theta_{legtop}) + 0.5⋅\dot{\theta}_{legtop} ⋅l_{leg2}⋅m_{leg2}⋅c
#
#
# 1}⋅sin(\theta_{body} + \theta_{legtop}) + 1.0⋅g⋅l_{leg1}⋅m_{leg2}⋅sin(\theta_{
#
#
# eta_{body} + \theta_{legtop}) + 1.0⋅g⋅l_{leg1}⋅m_{leg2}⋅sin(\theta_{body} + \t
#
#
#
#
#     2
# top} ⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legbot} + \theta_{legtop})
#
#
# os(\theta_{body} + \theta_{legbot} + \theta_{legtop}) + 1.0⋅g⋅m_{body} + 1.0⋅g
#
#
# body} + \theta_{legtop}) + 0.5⋅g⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{body} + \theta_
#
#
# heta_{legtop}) + 0.5⋅g⋅l_{leg2}⋅m_{leg2}⋅sin(\theta_{body} + \theta_{legbot} +
#
#
#
#
#                            ⎤
#                            ⎥
#                            ⎥
#                            ⎥
# ⋅m_{leg1} + 1.0⋅g⋅m_{leg2} ⎥
#                            ⎥
#                            ⎥
# {legbot} + \theta_{legtop})⎥
#                            ⎥
#                            ⎥
#  \theta_{legtop})          ⎥
#                            ⎥
#                            ⎥
#                            ⎦

# %%
# Position of monopod foot

pfoot = sym.Matrix([[x + ll1*sym.sin(thb + thlt) + ll2*sym.sin(thb + thlt + thlb)],
                    [y - ll1*sym.cos(thb + thlt) - ll2*sym.cos(thb + thlt + thlb)]])

pfoot

# %%
# Create an environment class for the monopod 
# functions: 
#   new_state, reward, terminated = env.step(previous_state, action)
#   env.plot(new_state)

class makeMonoEnv:
    """The monopod environment used for RL"""

    def __init__(self):
        self.mb = 5.0
        self.mlt = 2.5
        self.mlb = 2.5
        self.lb = 1.0
        self.llt = 0.5
        self.llb = 0.5
    
        self.Inb = 1/12*self.mb*self.lb**2
        self.Inlt = 1/12*self.mlt*self.llt**2
        self.Inlb = 1/12*self.mlb*self.llb**2
        
    def step(self, state, action):
        """step the RL model forward. 
        States should be [qx,... , qthlb, dqx,... , dqthlb, hm]
        Actions should be [tau_lt, tau_lb]"""
        
        qx_ = state[0]
        qy_ = state[1]
        
        terminate = False
        reward = 0
        new_state = 0
        
        return new_state, reward, terminate
        
    
    def f(self, number):
        return number*'hello world'

# %%
x = makeMonoEnv()
a,b,c = x.step(1,2)
c
# Out:
# False
