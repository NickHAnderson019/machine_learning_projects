# %% [markdown]
# # Trajectory Optimization of a monopod
# ## Generate training data for the ML neural net
#
# ### The general idea...
#
# Using trajectory optimization, locally optimal solutions can be found for a monopod performing a task. Using these trajectories, a ML model can be trained to predict, for a given state, what the control action (torque) should be.

# %% [markdown]
# ## Derive Equations of Motion

# %%
# %reset
# DERIVE THE EOMs SYMBOLICALLY ----------------------------------------------------------------------------------------------

# import libraries
import sympy as sym
import numpy as np

sym.init_printing()
from IPython.display import display #for pretty printing

# create symbolic variables

# system parameters
g = sym.symbols('g')
mb,ml1,ml2 = sym.symbols(['m_{body}','m_{leg1}','m_{leg2}']) # mass
lb,ll1,ll2 = sym.symbols(['l_{body}','l_{leg1}','l_{leg2}']) # length
Inb,Inl1,Inl2 = sym.symbols(['I_{body}','I_{leg1}','I_{leg2}']) # moment of intertia

# generalized coordinates
x,y,thb,thlt,thlb = sym.symbols(['x','y','\\theta_{body}','\\theta_{legtop}','\\theta_{legbot}']) 
dx,dy,dthb,dthlt,dthlb = sym.symbols(['\dot{x}','\dot{y}','\dot{\\theta}_{body}','\dot{\\theta}_{legtop}','\dot{\\theta}_{legbot}']) 
ddx,ddy,ddthb,ddthlt,ddthlb = sym.symbols(['\ddot{x}','\ddot{y}','\ddot{\\theta}_{body}','\ddot{\\theta}_{legtop}','\ddot{\\theta}_{legbot}']) 

q = sym.Matrix([[x],[y],[thb],[thlt],[thlb]])
dq = sym.Matrix([[dx],[dy],[dthb],[dthlt],[dthlb]])
ddq = sym.Matrix([[ddx],[ddy],[ddthb],[ddthlt],[ddthlb]])

# forces
# total joint action = actuator + rebound, but that will be dealt with elsewhere
tauh,tauk,GRFx,GRFy = sym.symbols(['\\tau_{hip}','\\tau_{knee}','G_x','G_y']) 

# STEP 1: position vectors ri = [x,y,theta] (world frame)
rb = sym.Matrix([[x],
                [y],
                [thb]])

rl1 = sym.Matrix([[x + 0.5*ll1*sym.sin(thb + thlt)],
                [y - 0.5*ll1*sym.cos(thb + thlt)],
                [thb + thlt]])

rl2 = sym.Matrix([[x + ll1*sym.sin(thb + thlt)+0.5*ll2*sym.sin(thb + thlt + thlb)],
                [y - ll1*sym.cos(thb + thlt) - 0.5*ll2*sym.cos(thb + thlt + thlb)],
                [thb + thlt + thlb]])

# the Jacobians
Jb = rb.jacobian(q)
Jl1 = rl1.jacobian(q)
Jl2 = rl2.jacobian(q)

# STEP 2: generate expressions for the system space velocities from the jacobians
vb = Jb*dq
vl1 = Jl1*dq
vl2 = Jl2*dq

# STEP 3: generate expressions for the kinetic and potential energy
# mass vectors
Mb = sym.Matrix([[mb,mb,Inb]])
Ml1 = sym.Matrix([[ml1,ml1,Inl1]])
Ml2 = sym.Matrix([[ml2,ml2,Inl2]])

T = 0.5*Mb*sym.matrix_multiply_elementwise(vb,vb) + 0.5*Ml1*sym.matrix_multiply_elementwise(vl1,vl1) + 0.5*Ml2*sym.matrix_multiply_elementwise(vl2,vl2)
T = T[0]
V = mb*g*rb[1] + ml1*g*rl1[1] + ml2*g*rl2[1]


# STEP 4: calculate each term of the Lagrange equation
# term 1
Lg1 = sym.zeros(len(q),1)
for i in range(len(q)):
    dT_ddq = sym.Matrix([sym.diff(T,dq[i])]) # get partial of T in dq_i
    Lg1[i] = dT_ddq.jacobian(q)*dq + dT_ddq.jacobian(dq)*ddq #...then get time derivative of that partial

# term 3
Lg3 = sym.Matrix([T]).jacobian(q).transpose() # partial of T in q

# term 4
Lg4 = sym.Matrix([V]).jacobian(q).transpose() # partial of U in q

# STEP 5: generalized forces

# force vectors for each link
tau_b = sym.Matrix([[0],[0],[-tauh]])
tau_l1 = sym.Matrix([[0],[0],[tauh-tauk]])
tau_l2 = sym.Matrix([[0],[0],[tauk]])

GRF_l2 = sym.Matrix([[GRFx],[GRFy],[0.5*ll2*GRFx*sym.cos(thb+thlt+thlb)+0.5*ll2*GRFy*sym.sin(thb+thlt+thlb)]])

Q = sym.zeros(len(q),1)
for j in range(len(q)):
    Q[j] = tau_b.transpose()*Jb[:,j]+(tau_l1).transpose()*Jl1[:,j]+(tau_l2+GRF_l2).transpose()*Jl2[:,j]

# AND combine!
EOM = Lg1 - Lg3 + Lg4 - Q

EOMs = sym.zeros(len(q),1)
for j in range(len(q)):
    EOMs[j] = EOM[j].simplify()
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# sym.solve(EOMs[4], ddq[4])

# %%
# Lambdify
from pyomo.environ import*
from pyomo.opt import SolverFactory
from pyomo.opt import SolverStatus, TerminationCondition
import time

func_map = {'sin':sin, 'cos':cos} 

sym_list = [g,mb,ml1,ml2,lb,ll1,ll2,Inb,Inl1,Inl2,
            x,y,thb,thlt,thlb,
            dx,dy,dthb,dthlt,dthlb,
            ddx,ddy,ddthb,ddthlt,ddthlb,
            tauh,tauk,GRFx,GRFy]
            
lambEOM_x = sym.lambdify(sym_list,EOMs[0],modules = [func_map])
lambEOM_y = sym.lambdify(sym_list,EOMs[1],modules = [func_map])
lambEOM_thb = sym.lambdify(sym_list,EOMs[2],modules = [func_map])
lambEOM_thlt = sym.lambdify(sym_list,EOMs[3],modules = [func_map])
lambEOM_thlb = sym.lambdify(sym_list,EOMs[4],modules = [func_map])

# %%
# rerun from here if you don't want to calculate the EOM's again
if 'm' in globals():
    del m # deletes the model
    
m = ConcreteModel()

# SETS-----------------------------------------------------------------------------------------------------------------------

T = 0.5 # total time
hm = 0.01 # master time step
N = int(T/hm) # number of nodes
m.N = RangeSet(N) 

links = [('body',1),('leg',1),('leg',2)]
m.L = Set(dimen=2, initialize = links)

DOFs = ['x','y','theta_b','theta_lt','theta_lb'] # generalized coordinates
m.DOF = Set(initialize = DOFs) 

# PARAMETERS-----------------------------------------------------------------------------------------------------------------

m.g = Param(initialize = 9.81)

def get_m(n, lb, ln):
    if lb == 'body':
        return 5.0
    else: return 2.5
m.m = Param(m.L, initialize = get_m) # mass of links

def get_len(n, lb, ln):
    if lb == 'body':
        return 1.0
    else: return 0.5
m.len = Param(m.L, initialize = get_len) # length of links

def calculate_In(m, lb, ln): 
    l = (lb,ln)
    # yes, that does mean you have to rebuild the tuple inside the function. Yes, it is dumb.
    return m.m[l]*m.len[l]**2/12 
m.In = Param(m.L, initialize = calculate_In) # moment of inertia

mbody = sum(m.m[l] for l in links)
BW = mbody*m.g.value

# VARIABLES -----------------------------------------------------------------------------------------------------------------

# system coordinates
m.q = Var(m.N, m.DOF) # position
m.dq = Var(m.N, m.DOF) # velocity
m.ddq = Var(m.N, m.DOF) # acceleration

# bound variables
for n in range(1,N+1):
    m.q[n,'y'].setlb(0.0)

# %%
# TIME AND INTEGRATION

# variable timestep
# hm = 0.02 # master timestep
m.h = Var(m.N, bounds = (0.8,1.2))

# Integration constraints 
def BwEuler_p(m,n,dof): # for positions
    if n > 1:
        return m.q[n,dof] == m.q[n-1,dof] + hm*m.h[n]*m.dq[n,dof]
    else:
        return Constraint.Skip
m.integrate_p = Constraint(m.N, m.DOF, rule = BwEuler_p)

def BwEuler_v(m,n,dof): # for velocities
    if n > 1:
        return m.dq[n,dof] == m.dq[n-1,dof] + hm*m.h[n]*m.ddq[n-1,dof]
    else:
        return Constraint.Skip 
m.integrate_v = Constraint(m.N, m.DOF, rule = BwEuler_v)

# %%
# GROUND INTERACTIONS -------------------------------------------------------------------------------------------------------

# paramters
m.mu = Param(initialize = 1.0) # friction coefficient

# sign set for positive and negative components
signs = ['ps','ng'] 
m.sgn = Set(initialize = signs)

WDOFs = ['X','Y',"THETA"] # absolute coordinates (see what I mean about switching between frames the whole time...?)
m.WDOF = Set(initialize = WDOFs) 

# variables
m.footp = Var(m.N, m.WDOF, bounds = (0.0,None)) # foot position
m.footv = Var(m.N, m.WDOF, m.sgn, bounds = (0.0,None)) # foot velocity

m.friction_cone = Var(m.N, bounds = (0.0,None))

m.GRF = Var(m.N, m.WDOF, m.sgn, bounds = (0.0,None)) # ground reaction forces

ground_constraints = ['contact','friction','slip_ps','slip_ng'] 
# ground_constraints = ['contact'] 
m.ground_constraints = Set(initialize = ground_constraints) # set for indexing ground-related penalties
m.ground_penalty = Var(m.N, m.ground_constraints, bounds = (0.0,None))

# constraints: aux variables
def def_footp(m,n,dof):
    if dof == 'Y':
        return m.footp[n,dof] == m.q[n,'y'] - m.len[('leg',1)]*cos(m.q[n,'theta_b']+m.q[n,'theta_lt']) - m.len[('leg',2)]*cos(m.q[n,'theta_b']+m.q[n,'theta_lt']+m.q[n,'theta_lb'])
    else:
        return Constraint.Skip
m.def_footp = Constraint(m.N, m.WDOF, rule = def_footp)

# lambdify the foot velocity
footx = sym.Matrix([x + ll1*sym.sin(thb + thlt) + ll2*sym.sin(thb + thlt + thlb)])
footdx = footx.jacobian(q)*dq
footdx = footdx[0].simplify()
lamb_footdx = sym.lambdify(sym_list,footdx,modules = [func_map])

def def_footv(m,n,dof):
    if dof == 'X':
        var_list = [m.g,m.m[('body',1)],m.m[('leg',1)],m.m[('leg',2)],
            m.len[('body',1)],m.len[('leg',1)],m.len[('leg',2)],
            m.In[('body',1)],m.In[('leg',1)],m.In[('leg',2)],
            m.q[n,'x'],m.q[n,'y'],m.q[n,'theta_b'],m.q[n,'theta_lt'],m.q[n,'theta_lb'],
            m.dq[n,'x'],m.dq[n,'y'],m.dq[n,'theta_b'],m.dq[n,'theta_lt'],m.dq[n,'theta_lb'],
            m.ddq[n,'x'],m.ddq[n,'y'],m.ddq[n,'theta_b'],m.ddq[n,'theta_lt'],m.ddq[n,'theta_lb'],
            0,0,0,0]
        return m.footv[n,dof,'ps']-m.footv[n,dof,'ng'] == lamb_footdx(*var_list)
    else:
        return Constraint.Skip
m.def_footv = Constraint(m.N, m.WDOF, rule = def_footv)

def def_friction_cone(m,n):
    return m.friction_cone[n] == m.mu*m.GRF[n,'Y','ps'] - (m.GRF[n,'X','ps'] + m.GRF[n,'X','ng'])
m.def_friction_cone = Constraint(m.N, rule = def_friction_cone)

# constraints: complementarity

# contact
def ground_contact(m,n):
    if n < N:
        return m.ground_penalty[n,'contact'] == m.footp[n+1,'Y']*m.GRF[n,'Y','ps'] 
    else:
        return Constraint.Skip
m.ground_contact = Constraint(m.N, rule = ground_contact)

# friction
def ground_friction(m,n):
    return m.ground_penalty[n,'friction'] == (m.footv[n,'X','ps']+m.footv[n,'X','ng'])*m.friction_cone[n]
m.ground_friction = Constraint(m.N, rule = ground_friction)

# slipping
def ground_slip_ps(m,n):
    return m.ground_penalty[n,'slip_ps'] == m.footv[n,'X','ps']*m.GRF[n,'X','ps']
m.ground_slip_ps = Constraint(m.N, rule = ground_slip_ps)

def ground_slip_ng(m,n):
    return m.ground_penalty[n,'slip_ng'] == m.footv[n,'X','ng']*m.GRF[n,'X','ng']
m.ground_slip_ng = Constraint(m.N, rule = ground_slip_ng)

# bound contact forces at last node
for dof in WDOFs:
    for sgn in signs:
        m.GRF[N,dof,sgn].value = 0
        m.GRF[N,dof,sgn].fixed = True

# %%
# HARD JOINT STOPS ----------------------------------------------------------------------------------------------------------

# sets
joints = ['hip','knee']
m.J = Set(initialize = joints)

joint_constraints = ['up','lo'] # set of joint penalties
m.joint_constraints = Set(initialize = joint_constraints)

# parameters
hip_bound = [-np.pi/2, np.pi/2]
m.hip_bound = Param(m.joint_constraints, initialize = {'up':hip_bound[1],'lo':hip_bound[0]}) 

knee_bound = [-np.pi, 0.0]
m.knee_bound = Param(m.joint_constraints, initialize = {'up':knee_bound[1],'lo':knee_bound[0]})

# we can bound the joint coordinates directly
for n in range(1,N+1):
    m.q[n,'theta_b'].setlb(-np.pi/2)
    m.q[n,'theta_b'].setub(np.pi/2)
    m.q[n,'theta_lt'].setlb(hip_bound[0])
    m.q[n,'theta_lt'].setub(hip_bound[1])
    m.q[n,'theta_lb'].setlb(knee_bound[0])
    m.q[n,'theta_lb'].setub(knee_bound[1])

# variables
m.tau_ah = Var(m.N, bounds = (-2,2)) # actuator torque at hip
m.tau_ak = Var(m.N, bounds = (-2,2)) # actuator torque at knee
m.tau_rh = Var(m.N, m.sgn, bounds = (0.0,None)) # rebound torque hip
m.tau_rk = Var(m.N, m.sgn, bounds = (0.0,None)) # rebound torque knee

m.joint_penalty = Var(m.N, m.J, m.joint_constraints, bounds = (0.0,None))

# complementarity
def hip_limits(m,n,jc):
    if n < N:
        if jc == 'up':
            # NEXT angle
            return m.joint_penalty[n,'hip',jc] == (m.hip_bound['up'] - m.q[n+1,'theta_lt'])*m.tau_rh[n,'ng']
        else:
            return m.joint_penalty[n,'hip',jc] == (m.q[n+1,'theta_lt'] - m.hip_bound['lo'])*m.tau_rh[n,'ps']
    else:
        return Constraint.Skip
m.hip_limits = Constraint(m.N, m.joint_constraints, rule = hip_limits)

def knee_limits(m,n,jc):
    if n < N:
        if jc == 'up':
            # NEXT angle
            return m.joint_penalty[n,'knee',jc] == (m.knee_bound['up'] - m.q[n+1,'theta_lb'])*m.tau_rk[n,'ng']
        else:
            return m.joint_penalty[n,'knee',jc] == (m.q[n+1,'theta_lb'] - m.knee_bound['lo'])*m.tau_rk[n,'ps']
    else:
        return Constraint.Skip
m.knee_limits = Constraint(m.N, m.joint_constraints, rule = knee_limits)

# bound contact forces at last node
for sgn in signs:
    m.tau_rh[N,sgn].fix(0.0)
    m.tau_rk[N,sgn].fix(0.0)

# %%
# COST FUNCTION -------------------------------------------------------------------------------------------------------------

# minimum time

def CostFun(m):
    T = sum(m.h[n] for n in range(1,N+1))
    penalty_sum = 0
    torque_sum = 0
    for n in range(1,N+1):
        for gc in ground_constraints:
            penalty_sum += m.ground_penalty[n,gc]
        for jc in joint_constraints:
            for j in joints:
                penalty_sum += m.joint_penalty[n,j,jc]
        torque_sum += (m.tau_ah[n]**2 + m.tau_ak[n]**2)*m.h[n] 
        
#     return T+1000*penalty_sum
    return torque_sum+1000*penalty_sum
m.Cost = Objective(rule = CostFun)

# %%
# EQUATIONS OF MOTION -------------------------------------------------------------------------------------------------------
S = BW

def EOM_x(m,n):
    tau_inh = S*(m.tau_ah[n])
    tau_ink = S*(m.tau_ak[n])
    Gx_in = S*(m.GRF[n,'X','ps']-m.GRF[n,'X','ng'])
    Gy_in = S*(m.GRF[n,'Y','ps'])
    
    var_list = [m.g,m.m[('body',1)],m.m[('leg',1)],m.m[('leg',2)],
            m.len[('body',1)],m.len[('leg',1)],m.len[('leg',2)],
            m.In[('body',1)],m.In[('leg',1)],m.In[('leg',2)],
            m.q[n,'x'],m.q[n,'y'],m.q[n,'theta_b'],m.q[n,'theta_lt'],m.q[n,'theta_lb'],
            m.dq[n,'x'],m.dq[n,'y'],m.dq[n,'theta_b'],m.dq[n,'theta_lt'],m.dq[n,'theta_lb'],
            m.ddq[n,'x'],m.ddq[n,'y'],m.ddq[n,'theta_b'],m.ddq[n,'theta_lt'],m.ddq[n,'theta_lb'],
            tau_inh,tau_ink,Gx_in,Gy_in]
    return lambEOM_x(*var_list) == 0
m.EOM_x = Constraint(m.N, rule = EOM_x)

def EOM_y(m,n):
    tau_inh = S*(m.tau_ah[n])
    tau_ink = S*(m.tau_ak[n])
    Gx_in = S*(m.GRF[n,'X','ps']-m.GRF[n,'X','ng'])
    Gy_in = S*(m.GRF[n,'Y','ps'])
    
    var_list = [m.g,m.m[('body',1)],m.m[('leg',1)],m.m[('leg',2)],
            m.len[('body',1)],m.len[('leg',1)],m.len[('leg',2)],
            m.In[('body',1)],m.In[('leg',1)],m.In[('leg',2)],
            m.q[n,'x'],m.q[n,'y'],m.q[n,'theta_b'],m.q[n,'theta_lt'],m.q[n,'theta_lb'],
            m.dq[n,'x'],m.dq[n,'y'],m.dq[n,'theta_b'],m.dq[n,'theta_lt'],m.dq[n,'theta_lb'],
            m.ddq[n,'x'],m.ddq[n,'y'],m.ddq[n,'theta_b'],m.ddq[n,'theta_lt'],m.ddq[n,'theta_lb'],
            tau_inh,tau_ink,Gx_in,Gy_in]
    return lambEOM_y(*var_list) == 0
m.EOM_y = Constraint(m.N, rule = EOM_y)

def EOM_thb(m,n):
    tau_inh = S*(m.tau_ah[n])
    tau_ink = S*(m.tau_ak[n])
    Gx_in = S*(m.GRF[n,'X','ps']-m.GRF[n,'X','ng'])
    Gy_in = S*(m.GRF[n,'Y','ps'])
    
    var_list = [m.g,m.m[('body',1)],m.m[('leg',1)],m.m[('leg',2)],
            m.len[('body',1)],m.len[('leg',1)],m.len[('leg',2)],
            m.In[('body',1)],m.In[('leg',1)],m.In[('leg',2)],
            m.q[n,'x'],m.q[n,'y'],m.q[n,'theta_b'],m.q[n,'theta_lt'],m.q[n,'theta_lb'],
            m.dq[n,'x'],m.dq[n,'y'],m.dq[n,'theta_b'],m.dq[n,'theta_lt'],m.dq[n,'theta_lb'],
            m.ddq[n,'x'],m.ddq[n,'y'],m.ddq[n,'theta_b'],m.ddq[n,'theta_lt'],m.ddq[n,'theta_lb'],
            tau_inh,tau_ink,Gx_in,Gy_in]
    return lambEOM_thb(*var_list) == 0
m.EOM_thb = Constraint(m.N, rule = EOM_thb)

def EOM_thlt(m,n):
    tau_inh = S*(m.tau_ah[n])
    tau_ink = S*(m.tau_ak[n])
    Gx_in = S*(m.GRF[n,'X','ps']-m.GRF[n,'X','ng'])
    Gy_in = S*(m.GRF[n,'Y','ps'])
    
    var_list = [m.g,m.m[('body',1)],m.m[('leg',1)],m.m[('leg',2)],
            m.len[('body',1)],m.len[('leg',1)],m.len[('leg',2)],
            m.In[('body',1)],m.In[('leg',1)],m.In[('leg',2)],
            m.q[n,'x'],m.q[n,'y'],m.q[n,'theta_b'],m.q[n,'theta_lt'],m.q[n,'theta_lb'],
            m.dq[n,'x'],m.dq[n,'y'],m.dq[n,'theta_b'],m.dq[n,'theta_lt'],m.dq[n,'theta_lb'],
            m.ddq[n,'x'],m.ddq[n,'y'],m.ddq[n,'theta_b'],m.ddq[n,'theta_lt'],m.ddq[n,'theta_lb'],
            tau_inh,tau_ink,Gx_in,Gy_in]
    return lambEOM_thlt(*var_list) == 0
m.EOM_thlt = Constraint(m.N, rule = EOM_thlt)

def EOM_thlb(m,n):
    tau_inh = S*(m.tau_ah[n])
    tau_ink = S*(m.tau_ak[n])
    Gx_in = S*(m.GRF[n,'X','ps']-m.GRF[n,'X','ng'])
    Gy_in = S*(m.GRF[n,'Y','ps'])
    
    var_list = [m.g,m.m[('body',1)],m.m[('leg',1)],m.m[('leg',2)],
            m.len[('body',1)],m.len[('leg',1)],m.len[('leg',2)],
            m.In[('body',1)],m.In[('leg',1)],m.In[('leg',2)],
            m.q[n,'x'],m.q[n,'y'],m.q[n,'theta_b'],m.q[n,'theta_lt'],m.q[n,'theta_lb'],
            m.dq[n,'x'],m.dq[n,'y'],m.dq[n,'theta_b'],m.dq[n,'theta_lt'],m.dq[n,'theta_lb'],
            m.ddq[n,'x'],m.ddq[n,'y'],m.ddq[n,'theta_b'],m.ddq[n,'theta_lt'],m.ddq[n,'theta_lb'],
            tau_inh,tau_ink,Gx_in,Gy_in]
    return lambEOM_thlb(*var_list) == 0
m.EOM_thlb = Constraint(m.N, rule = EOM_thlb)

# %%
def def_q_periodic(m, dof): # periodicity in position
    if dof == 'x':
        return Constraint.Skip
    else:
        return m.q[1, dof] == m.q[N, dof]
m.def_q_periodic = Constraint(m.DOF, rule = def_q_periodic)

def def_dq_periodic(m, dof): # periodicity in velocity
    return m.dq[1, dof] == m.dq[N, dof]
m.def_dq_periodic = Constraint(m.DOF, rule = def_dq_periodic)

# %%
# Define periodic gate stuff
import random

x_0_lb = -1.0 # -1 m
x_0_ub = 1.0 # 1 m
penalty_thresh = 1e-6
iterations = 1000

# Periodic Gate -------------------------------------------------------------------------------------------------------------

opt = SolverFactory('ipopt',executable = '/home/alex/CoinIpoptBackup/build/bin/ipopt')
opt.options["linear_solver"] = 'ma86'

# solver options
opt.options["expect_infeasible_problem"] = 'yes'
#opt.options["linear_system_scaling"] = 'none'
#opt.options["mu_strategy"] = "adaptive"
opt.options["print_level"] = 5 # prints a log with each iteration (you want to this - it's the only way to see progress.)
opt.options["max_iter"] = 30000 # maximum number of iterations
opt.options["max_cpu_time"] = 120 # maximum cpu time in seconds
opt.options["Tol"] = 1e-6 # the tolerance for feasibility. Considers constraints satisfied when they're within this margin.

# %%
print('{0:<20s}{1:<20s}{2:<25s}{3:<20s}'.format("Iteration","Solved","Penalty","Time (s)"))
failed_solves = 0
success_solves = 0

for i in range(1,iterations+1):
    if 'm_sim' in globals():
        del m_sim
    
    m_sim = m.clone() # create a clean model
    
    m_sim.q[1,'x'].fix(np.random.uniform(x_0_lb, x_0_ub)) # initial condition
    
    vx_avg = float(random.randint(-4.0,4.0)) # 4 m/s
 
    def def_vx (m_sim):
        return vx_avg == (m_sim.q[N,'x'] - m_sim.q[1,'x'])/sum(m_sim.h[:])/hm
    m_sim.def_vx = Constraint(rule = def_vx)
    
    try:
        start = time.time()
        # solving
        results = opt.solve(m_sim, tee = False) 
        end = time.time()
    
    except:
        print("Something went wrong with solve...")
        failed_solves += 1
        continue
    
    if str(results.solver.termination_condition) == "optimal":
        penalty_sum = 0
        for n in range(1,N+1):
            for gc in ground_constraints:
                penalty_sum += m_sim.ground_penalty[n,gc].value
            for jc in joint_constraints:
                for j in joints:
                    penalty_sum += m_sim.joint_penalty[n,j,jc].value
    
    else: 
        penalty_sum = 0
    
    print('{0:<20s}{1:<20s}{2:<25}{3:<20d}'.format(str(i)+"/"+str(iterations), str(results.solver.termination_condition),penalty_sum,round(end-start)))
    
    if str(results.solver.termination_condition) == "optimal" and penalty_sum < penalty_thresh:
        qx_ar = np.array([m_sim.q[i,'x'].value for i in range(1, N+1)])
        qy_ar = np.array([m_sim.q[i,'y'].value for i in range(1, N+1)])
        qthb_ar = np.array([m_sim.q[i,'theta_b'].value for i in range(1, N+1)])
        qthlt_ar = np.array([m_sim.q[i,'theta_lt'].value for i in range(1, N+1)])
        qthlb_ar = np.array([m_sim.q[i,'theta_lb'].value for i in range(1, N+1)])
        tauh_ar = np.array([m_sim.tau_ah[i].value for i in range(1, N+1)])
        tauk_ar = np.array([m_sim.tau_ak[i].value for i in range(1, N+1)])

        if vx_avg >= 0:
            vx_avg_str = "p" + str(int(vx_avg))
        elif vx_avg < 0:
            vx_avg_str = "n" + str(abs(int(vx_avg)))

        filename = "iter_" + str(i) + "_" + vx_avg_str + "ms.npy"

        filepath = "./Datasets/test1/"

        file = filepath + filename
        np.save(file, [qx_ar, qy_ar, qthb_ar, qthlt_ar, qthlb_ar, vx_avg, tauh_ar, tauk_ar])
        print("Saved file:", file)
        success_solves += 1
    else:
        print("Failed")
        failed_solves += 1
#     m.del_component(m_sim.def_vx)


print("---------------------------------------------------------------------")
print("Batch finished.")
print("Percetage sucessful solves:", round(success_solves/iterations*100), "%")
# Out:
# Iteration           Solved              Penalty                  Time (s)
# 1/1000              optimal             4.247688143844644e-08    5
# Saved file: ./Datasets/test1/iter_1_p0ms.npy
# 2/1000              optimal             3.0620791504454485e-08   48
# Saved file: ./Datasets/test1/iter_2_n1ms.npy
# Something went wrong with solve...
# 4/1000              optimal             4.443191930882187e-08    4
# Saved file: ./Datasets/test1/iter_4_p0ms.npy
# 5/1000              optimal             2.2351394048755643e-08   42
# Saved file: ./Datasets/test1/iter_5_p2ms.npy
# Something went wrong with solve...
# 7/1000              optimal             2.4262743139890235e-08   29
# Saved file: ./Datasets/test1/iter_7_n4ms.npy
# 8/1000              optimal             2.6218502488332296e-08   31
# Saved file: ./Datasets/test1/iter_8_n4ms.npy
# 9/1000              optimal             2.8647035191122876e-08   38
# Saved file: ./Datasets/test1/iter_9_n1ms.npy
# Something went wrong with solve...
# 11/1000             optimal             1.5260916080240953e-08   29
# Saved file: ./Datasets/test1/iter_11_p2ms.npy
# Something went wrong with solve...
# 13/1000             optimal             6.273399363051417e-09    27
# Saved file: ./Datasets/test1/iter_13_n4ms.npy
# 14/1000             optimal             1.1854272392889212e-08   24
# Saved file: ./Datasets/test1/iter_14_p3ms.npy
# Something went wrong with solve...
# 16/1000             optimal             1.042973279425443e-08    23
# Saved file: ./Datasets/test1/iter_16_p3ms.npy
# 17/1000             optimal             1.769444357379829e-08    62
# Saved file: ./Datasets/test1/iter_17_n1ms.npy
# 18/1000             optimal             2.591356614640833e-08    37
# Saved file: ./Datasets/test1/iter_18_n1ms.npy
# 19/1000             optimal             2.931510819794628e-08    51
# Saved file: ./Datasets/test1/iter_19_n1ms.npy
# Something went wrong with solve...
# 21/1000             optimal             7.898618795017508e-08    45
# Saved file: ./Datasets/test1/iter_21_p4ms.npy
# 22/1000             optimal             9.51801941093345e-09     20
# Saved file: ./Datasets/test1/iter_22_p3ms.npy
# 23/1000             optimal             6.432181947828929e-09    23
# Saved file: ./Datasets/test1/iter_23_n4ms.npy
# 24/1000             optimal             9.250521852561522e-09    26
# Saved file: ./Datasets/test1/iter_24_p3ms.npy
# 25/1000             optimal             3.898743387963444e-08    30
# Saved file: ./Datasets/test1/iter_25_p1ms.npy
# Something went wrong with solve...
# 27/1000             optimal             3.653675934885091e-08    35
# Saved file: ./Datasets/test1/iter_27_n3ms.npy
# 28/1000             optimal             1.0296782080871847e-08   33
# Saved file: ./Datasets/test1/iter_28_p3ms.npy
# 29/1000             optimal             7.776810313897094e-08    62
# Saved file: ./Datasets/test1/iter_29_n3ms.npy
# 30/1000             optimal             2.2900181346418074e-08   48
# Saved file: ./Datasets/test1/iter_30_n1ms.npy
# 31/1000             optimal             8.276121623766601e-09    30
# Saved file: ./Datasets/test1/iter_31_p3ms.npy
# 32/1000             optimal             2.534698633270027e-08    24
# Saved file: ./Datasets/test1/iter_32_n4ms.npy
# 33/1000             optimal             2.9130044342321193e-08   29
# Saved file: ./Datasets/test1/iter_33_n1ms.npy
# 34/1000             optimal             5.347851473682804e-08    32
# Saved file: ./Datasets/test1/iter_34_p1ms.npy
# 35/1000             optimal             2.022413172455861e-08    25
# Saved file: ./Datasets/test1/iter_35_n4ms.npy
# 36/1000             optimal             3.574394164483233e-08    35
# Saved file: ./Datasets/test1/iter_36_p4ms.npy
# 37/1000             optimal             7.217793655922544e-08    39
# Saved file: ./Datasets/test1/iter_37_p2ms.npy
# 38/1000             optimal             8.616290669878672e-09    32
# Saved file: ./Datasets/test1/iter_38_n4ms.npy
# 39/1000             optimal             3.388891968493671e-08    78
# Saved file: ./Datasets/test1/iter_39_p3ms.npy
# 40/1000             optimal             5.014473863931024e-08    36
# Saved file: ./Datasets/test1/iter_40_n2ms.npy
# Something went wrong with solve...
# 42/1000             optimal             4.338239577144853e-08    24
# Saved file: ./Datasets/test1/iter_42_p1ms.npy
# 43/1000             optimal             5.4219634403011435e-08   39
# Saved file: ./Datasets/test1/iter_43_p1ms.npy
# 44/1000             optimal             9.573083108321378e-09    29
# Saved file: ./Datasets/test1/iter_44_p3ms.npy
# 45/1000             optimal             5.824928231295206e-08    37
# Saved file: ./Datasets/test1/iter_45_n1ms.npy
# 46/1000             optimal             3.098141334940523e-08    34
# Saved file: ./Datasets/test1/iter_46_p1ms.npy
# 47/1000             optimal             6.358915443688218e-08    45
# Saved file: ./Datasets/test1/iter_47_n3ms.npy
# 48/1000             optimal             3.351268158230391e-08    90
# Saved file: ./Datasets/test1/iter_48_n3ms.npy
# 49/1000             optimal             1.3216973713693507e-08   33
# Saved file: ./Datasets/test1/iter_49_n2ms.npy
# 50/1000             optimal             2.390469845168686e-08    31
# Saved file: ./Datasets/test1/iter_50_p3ms.npy
# Something went wrong with solve...
# 52/1000             optimal             2.8315328709405778e-08   38
# Saved file: ./Datasets/test1/iter_52_n1ms.npy
# 53/1000             optimal             4.6407808681346877e-08   3
# Saved file: ./Datasets/test1/iter_53_p0ms.npy
# 54/1000             optimal             1.0502455198800532e-08   29
# Saved file: ./Datasets/test1/iter_54_n4ms.npy
# 55/1000             optimal             5.771689088272673e-09    26
# Saved file: ./Datasets/test1/iter_55_p3ms.npy
# 56/1000             optimal             3.6999722549608476e-08   35
# Saved file: ./Datasets/test1/iter_56_p2ms.npy
# 57/1000             optimal             2.1081651725107055e-08   31
# Saved file: ./Datasets/test1/iter_57_p2ms.npy
# 58/1000             optimal             1.2928542031185044e-08   26
# Saved file: ./Datasets/test1/iter_58_p2ms.npy
# Something went wrong with solve...
# 60/1000             optimal             3.213149255287017e-08    33
# Saved file: ./Datasets/test1/iter_60_p2ms.npy
# 61/1000             optimal             3.304980396319416e-08    49
# Saved file: ./Datasets/test1/iter_61_n1ms.npy
# 62/1000             optimal             1.4389300896753191e-08   30
# Saved file: ./Datasets/test1/iter_62_n2ms.npy
# 63/1000             optimal             1.4347966826741847e-08   30
# Saved file: ./Datasets/test1/iter_63_n2ms.npy
# 64/1000             optimal             4.9312172862889676e-08   40
# Saved file: ./Datasets/test1/iter_64_n2ms.npy
# 65/1000             optimal             4.74119291879695e-08     36
# Saved file: ./Datasets/test1/iter_65_p2ms.npy
# 66/1000             optimal             2.064773701584794e-08    20
# Saved file: ./Datasets/test1/iter_66_n3ms.npy
# 67/1000             optimal             3.1399168758804225e-08   26
# Saved file: ./Datasets/test1/iter_67_p2ms.npy
# 68/1000             optimal             3.9201908363071805e-08   44
# Saved file: ./Datasets/test1/iter_68_n1ms.npy
# 69/1000             optimal             1.1640766438697646e-08   35
# Saved file: ./Datasets/test1/iter_69_n3ms.npy
# 70/1000             optimal             1.921481191594238e-08    25
# Saved file: ./Datasets/test1/iter_70_n4ms.npy
# 71/1000             optimal             1.6895536198379582e-07   41
# Saved file: ./Datasets/test1/iter_71_n1ms.npy
# 72/1000             optimal             1.2414047507837809e-08   31
# Saved file: ./Datasets/test1/iter_72_n3ms.npy
# Something went wrong with solve...
# 74/1000             optimal             3.357232673186063e-08    6
# Saved file: ./Datasets/test1/iter_74_p0ms.npy
# 75/1000             optimal             4.2663407966881105e-08   25
# Saved file: ./Datasets/test1/iter_75_p1ms.npy
# 76/1000             optimal             1.4355597439688424e-08   31
# Saved file: ./Datasets/test1/iter_76_n2ms.npy
# 77/1000             optimal             9.13217526360448e-09     24
# Saved file: ./Datasets/test1/iter_77_p2ms.npy
# 78/1000             optimal             3.070660123442412e-08    7
# Saved file: ./Datasets/test1/iter_78_p0ms.npy
# 79/1000             optimal             2.5639833781175563e-08   27
# Saved file: ./Datasets/test1/iter_79_p1ms.npy
# 80/1000             optimal             1.2984326934060952e-08   36
# Saved file: ./Datasets/test1/iter_80_n3ms.npy
# Something went wrong with solve...
# 82/1000             optimal             7.273191054052691e-09    34
# Saved file: ./Datasets/test1/iter_82_n4ms.npy
# 83/1000             optimal             3.658479415763243e-08    31
# Saved file: ./Datasets/test1/iter_83_p1ms.npy
# 84/1000             optimal             4.4464934492035186e-08   5
# Saved file: ./Datasets/test1/iter_84_p0ms.npy
# Something went wrong with solve...
# 86/1000             optimal             3.824563456529755e-08    39
# Saved file: ./Datasets/test1/iter_86_p2ms.npy
# 87/1000             optimal             8.827600404326164e-09    24
# Saved file: ./Datasets/test1/iter_87_n4ms.npy
# Something went wrong with solve...
# 89/1000             optimal             1.1622611767691542e-08   34
# Saved file: ./Datasets/test1/iter_89_p4ms.npy
# 90/1000             optimal             1.8882177618078043e-08   40
# Saved file: ./Datasets/test1/iter_90_p2ms.npy
# 91/1000             optimal             2.5802482245930117e-08   28
# Saved file: ./Datasets/test1/iter_91_n4ms.npy
# 92/1000             optimal             5.128538152981707e-08    25
# Saved file: ./Datasets/test1/iter_92_p1ms.npy
# 93/1000             optimal             9.477104929801264e-09    27
# Saved file: ./Datasets/test1/iter_93_p4ms.npy
# Something went wrong with solve...
# 95/1000             optimal             1.2518719050621388e-08   33
# Saved file: ./Datasets/test1/iter_95_p4ms.npy
# 96/1000             optimal             4.827414773152755e-08    2
# Saved file: ./Datasets/test1/iter_96_p0ms.npy
# 97/1000             optimal             3.9098328550726154e-08   27
# Saved file: ./Datasets/test1/iter_97_p1ms.npy
# 98/1000             optimal             2.4690175629886894e-08   80
# Saved file: ./Datasets/test1/iter_98_n3ms.npy
# 99/1000             optimal             8.864458424109896e-09    40
# Saved file: ./Datasets/test1/iter_99_p4ms.npy
# 100/1000            optimal             1.3085157936231293e-08   18
# Saved file: ./Datasets/test1/iter_100_n2ms.npy
# 101/1000            optimal             3.654053187397508e-08    8
# Saved file: ./Datasets/test1/iter_101_p0ms.npy
# 102/1000            optimal             4.694523194309475e-08    2
# Saved file: ./Datasets/test1/iter_102_p0ms.npy
# 103/1000            optimal             3.303291730292992e-08    7
# Saved file: ./Datasets/test1/iter_103_p0ms.npy
# 104/1000            optimal             6.027193521451806e-09    27
# Saved file: ./Datasets/test1/iter_104_n3ms.npy
# 105/1000            optimal             3.7117158994879615e-08   45
# Saved file: ./Datasets/test1/iter_105_p2ms.npy
# 106/1000            optimal             5.611800686229571e-08    27
# Saved file: ./Datasets/test1/iter_106_p1ms.npy
# 107/1000            optimal             4.344563916927275e-08    3
# Saved file: ./Datasets/test1/iter_107_p0ms.npy
# 108/1000            optimal             9.84424920200805e-09     21
# Saved file: ./Datasets/test1/iter_108_p2ms.npy
# 109/1000            optimal             2.5924103610291243e-08   32
# Saved file: ./Datasets/test1/iter_109_p1ms.npy
# 110/1000            optimal             1.411312289382711e-08    26
# Saved file: ./Datasets/test1/iter_110_n2ms.npy
# 111/1000            optimal             1.4211715382761229e-08   26
# Saved file: ./Datasets/test1/iter_111_n2ms.npy
# Something went wrong with solve...
# 113/1000            optimal             1.1745739878738563e-08   32
# Saved file: ./Datasets/test1/iter_113_p4ms.npy
# 114/1000            optimal             2.0192767123284447e-08   33
# Saved file: ./Datasets/test1/iter_114_n4ms.npy
# 115/1000            optimal             1.21337064576067e-08     30
# Saved file: ./Datasets/test1/iter_115_p4ms.npy
# 116/1000            optimal             1.203863361509137e-08    29
# Saved file: ./Datasets/test1/iter_116_p4ms.npy
# 117/1000            optimal             1.4427004852115476e-08   31
# Saved file: ./Datasets/test1/iter_117_p4ms.npy
# 118/1000            optimal             9.585579549732175e-09    24
# Saved file: ./Datasets/test1/iter_118_p2ms.npy
# 119/1000            optimal             4.4280186526447993e-08   40
# Saved file: ./Datasets/test1/iter_119_n2ms.npy
# 120/1000            optimal             4.067998508488452e-08    30
# Saved file: ./Datasets/test1/iter_120_p2ms.npy
# 121/1000            optimal             3.574033478348964e-08    32
# Saved file: ./Datasets/test1/iter_121_p1ms.npy
# 122/1000            optimal             8.521915248000217e-09    24
# Saved file: ./Datasets/test1/iter_122_n4ms.npy
# 123/1000            optimal             1.2881864989752695e-08   27
# Saved file: ./Datasets/test1/iter_123_p2ms.npy
# 124/1000            optimal             6.3646811111048786e-09   30
# Saved file: ./Datasets/test1/iter_124_n4ms.npy
# 125/1000            optimal             1.2363059803752954e-08   26
# Saved file: ./Datasets/test1/iter_125_n2ms.npy
# 126/1000            optimal             1.0208474347689082e-08   27
# Saved file: ./Datasets/test1/iter_126_p3ms.npy
# Something went wrong with solve...
# 128/1000            optimal             6.619579802446142e-09    28
# Saved file: ./Datasets/test1/iter_128_n2ms.npy
# 129/1000            optimal             4.559745792243814e-08    58
# Saved file: ./Datasets/test1/iter_129_n1ms.npy
# 130/1000            optimal             3.0065771011743936e-08   28
# Saved file: ./Datasets/test1/iter_130_p2ms.npy
# 131/1000            optimal             1.8911778831058885e-08   42
# Saved file: ./Datasets/test1/iter_131_n1ms.npy
# 132/1000            optimal             2.7883139381083488e-08   30
# Saved file: ./Datasets/test1/iter_132_p4ms.npy
# 133/1000            optimal             1.0196385517954519e-08   22
# Saved file: ./Datasets/test1/iter_133_p3ms.npy
# 134/1000            optimal             8.420363532797515e-09    29
# Saved file: ./Datasets/test1/iter_134_p3ms.npy
# 135/1000            optimal             1.3043357835175322e-08   43
# Saved file: ./Datasets/test1/iter_135_n1ms.npy
# 136/1000            optimal             5.868884067258742e-08    50
# Saved file: ./Datasets/test1/iter_136_n3ms.npy
# 137/1000            optimal             1.3947228496570019e-08   30
# Saved file: ./Datasets/test1/iter_137_p4ms.npy
# 138/1000            optimal             4.80469123431227e-08     1
# Saved file: ./Datasets/test1/iter_138_p0ms.npy
# 139/1000            optimal             2.330954050860129e-08    43
# Saved file: ./Datasets/test1/iter_139_n2ms.npy
# 140/1000            optimal             8.660191803861106e-09    26
# Saved file: ./Datasets/test1/iter_140_p2ms.npy
# 141/1000            optimal             1.1175035017904187e-08   25
# Saved file: ./Datasets/test1/iter_141_n3ms.npy
# 142/1000            optimal             3.605603781756365e-08    29
# Saved file: ./Datasets/test1/iter_142_n1ms.npy
# 143/1000            optimal             1.6625361376672346e-08   27
# Saved file: ./Datasets/test1/iter_143_p2ms.npy
# 144/1000            optimal             1.2954125841359115e-08   28
# Saved file: ./Datasets/test1/iter_144_p3ms.npy
# 145/1000            optimal             9.418480975416991e-09    26
# Saved file: ./Datasets/test1/iter_145_n4ms.npy
# 146/1000            optimal             8.995775992904406e-09    30
# Saved file: ./Datasets/test1/iter_146_p4ms.npy
# 147/1000            optimal             1.386166640684969e-08    48
# Saved file: ./Datasets/test1/iter_147_n4ms.npy
# 148/1000            optimal             4.2907039685660284e-08   35
# Saved file: ./Datasets/test1/iter_148_p1ms.npy
# 149/1000            optimal             2.7037482560809785e-08   31
# Saved file: ./Datasets/test1/iter_149_n4ms.npy
# 150/1000            optimal             2.088876615270536e-08    41
# Saved file: ./Datasets/test1/iter_150_p2ms.npy
# 151/1000            optimal             2.4220305837779e-08      23
# Saved file: ./Datasets/test1/iter_151_n4ms.npy
# 152/1000            optimal             1.380089872621702e-08    29
# Saved file: ./Datasets/test1/iter_152_p2ms.npy
# 153/1000            optimal             1.4492746148160741e-08   23
# Saved file: ./Datasets/test1/iter_153_p3ms.npy
# 154/1000            optimal             2.380579606829783e-08    50
# Saved file: ./Datasets/test1/iter_154_p4ms.npy
# 155/1000            optimal             1.0114557468148345e-08   25
# Saved file: ./Datasets/test1/iter_155_p3ms.npy
# Something went wrong with solve...
# 157/1000            optimal             1.0361504616967398e-08   30
# Saved file: ./Datasets/test1/iter_157_n2ms.npy
# Something went wrong with solve...
# 159/1000            optimal             9.841657352539948e-09    25
# Saved file: ./Datasets/test1/iter_159_n3ms.npy
# 160/1000            optimal             1.3358006633019902e-08   28
# Saved file: ./Datasets/test1/iter_160_n2ms.npy
# Something went wrong with solve...
# 162/1000            optimal             3.32725579197811e-08     9
# Saved file: ./Datasets/test1/iter_162_p0ms.npy
# 163/1000            optimal             1.950914533696319e-08    25
# Saved file: ./Datasets/test1/iter_163_n4ms.npy
# 164/1000            optimal             1.3487306974333248e-08   79
# Saved file: ./Datasets/test1/iter_164_n3ms.npy
# 165/1000            optimal             1.362860768842716e-08    35
# Saved file: ./Datasets/test1/iter_165_p4ms.npy
# 166/1000            optimal             3.997931302918438e-08    43
# Saved file: ./Datasets/test1/iter_166_p1ms.npy
# 167/1000            optimal             1.345226926143614e-08    29
# Saved file: ./Datasets/test1/iter_167_p4ms.npy
# 168/1000            optimal             4.268187224051104e-08    30
# Saved file: ./Datasets/test1/iter_168_p1ms.npy
# 169/1000            optimal             5.52413975192529e-08     47
# Saved file: ./Datasets/test1/iter_169_n2ms.npy
# 170/1000            optimal             1.1242700260545846e-08   27
# Saved file: ./Datasets/test1/iter_170_p2ms.npy
# 171/1000            optimal             3.739695874594427e-08    26
# Saved file: ./Datasets/test1/iter_171_p1ms.npy
# 172/1000            optimal             3.883977011481514e-08    33
# Saved file: ./Datasets/test1/iter_172_p1ms.npy
# 173/1000            optimal             1.557144544368911e-08    54
# Saved file: ./Datasets/test1/iter_173_p4ms.npy
# 174/1000            optimal             3.94930843052575e-08     6
# Saved file: ./Datasets/test1/iter_174_p0ms.npy
# 175/1000            optimal             9.919992885644661e-09    30
# Saved file: ./Datasets/test1/iter_175_n3ms.npy
# 176/1000            optimal             3.298875225479825e-08    44
# Saved file: ./Datasets/test1/iter_176_n3ms.npy
# 177/1000            optimal             6.614720902339394e-09    20
# Saved file: ./Datasets/test1/iter_177_n3ms.npy
# 178/1000            optimal             2.080087304719691e-08    36
# Saved file: ./Datasets/test1/iter_178_p4ms.npy
# 179/1000            optimal             1.6526439376226237e-08   33
# Saved file: ./Datasets/test1/iter_179_p4ms.npy
# 180/1000            optimal             3.4930982613143934e-08   25
# Saved file: ./Datasets/test1/iter_180_p1ms.npy
# 181/1000            optimal             2.6763791597204732e-08   51
# Saved file: ./Datasets/test1/iter_181_n1ms.npy
# 182/1000            optimal             2.493292622015349e-08    35
# Saved file: ./Datasets/test1/iter_182_n4ms.npy
# 183/1000            optimal             1.0980201493965982e-08   30
# Saved file: ./Datasets/test1/iter_183_p4ms.npy
# 184/1000            optimal             4.7868552003223244e-08   1
# Saved file: ./Datasets/test1/iter_184_p0ms.npy
# 185/1000            optimal             2.8677610150771694e-08   24
# Saved file: ./Datasets/test1/iter_185_p3ms.npy
# 186/1000            optimal             1.0322577695390243e-08   32
# Saved file: ./Datasets/test1/iter_186_p3ms.npy
# 187/1000            optimal             8.50660043503845e-09     35
# Saved file: ./Datasets/test1/iter_187_p4ms.npy
# 188/1000            optimal             6.579380351625226e-08    38
# Saved file: ./Datasets/test1/iter_188_n2ms.npy
# 189/1000            optimal             2.2379068367980808e-08   28
# Saved file: ./Datasets/test1/iter_189_n4ms.npy
# 190/1000            optimal             2.1765512207824177e-08   27
# Saved file: ./Datasets/test1/iter_190_n4ms.npy
# 191/1000            optimal             3.571488140224509e-08    32
# Saved file: ./Datasets/test1/iter_191_p2ms.npy
# 192/1000            optimal             1.3079886474566688e-08   30
# Saved file: ./Datasets/test1/iter_192_n2ms.npy
# 193/1000            optimal             3.3917843951869936e-08   42
# Saved file: ./Datasets/test1/iter_193_p2ms.npy
# 194/1000            optimal             4.533111015694943e-08    28
# Saved file: ./Datasets/test1/iter_194_p1ms.npy
# 195/1000            optimal             1.855094827221511e-08    29
# Saved file: ./Datasets/test1/iter_195_p1ms.npy
# 196/1000            optimal             8.557612794481339e-09    29
# Saved file: ./Datasets/test1/iter_196_p3ms.npy
# 197/1000            optimal             3.8839770114815086e-08   30
# Saved file: ./Datasets/test1/iter_197_p1ms.npy
# 198/1000            optimal             5.17464924799162e-08     38
# Saved file: ./Datasets/test1/iter_198_p2ms.npy
# 199/1000            optimal             1.8805761577840586e-08   36
# Saved file: ./Datasets/test1/iter_199_p4ms.npy
# 200/1000            optimal             9.754537223065956e-09    26
# Saved file: ./Datasets/test1/iter_200_p3ms.npy
# Something went wrong with solve...
# 202/1000            optimal             2.7033844710545164e-08   35
# Saved file: ./Datasets/test1/iter_202_n2ms.npy
# 203/1000            optimal             3.672786182219124e-08    35
# Saved file: ./Datasets/test1/iter_203_n3ms.npy
# 204/1000            optimal             3.75588843990674e-08     44
# Saved file: ./Datasets/test1/iter_204_n1ms.npy
# 205/1000            optimal             1.8943323372857468e-08   43
# Saved file: ./Datasets/test1/iter_205_p4ms.npy
# 206/1000            optimal             5.612802632654048e-08    27
# Saved file: ./Datasets/test1/iter_206_p1ms.npy
# 207/1000            optimal             3.626154999503469e-08    40
# Saved file: ./Datasets/test1/iter_207_p1ms.npy
# 208/1000            optimal             4.631739083221702e-08    3
# Saved file: ./Datasets/test1/iter_208_p0ms.npy
# 209/1000            optimal             2.702865794715739e-08    39
# Saved file: ./Datasets/test1/iter_209_p3ms.npy
# 210/1000            optimal             3.3572326732205147e-08   6
# Saved file: ./Datasets/test1/iter_210_p0ms.npy
# 211/1000            optimal             1.872466867580692e-08    25
# Saved file: ./Datasets/test1/iter_211_n4ms.npy
# 212/1000            optimal             1.3900407024074372e-08   39
# Saved file: ./Datasets/test1/iter_212_p4ms.npy
# 213/1000            optimal             8.35647605326001e-09     22
# Saved file: ./Datasets/test1/iter_213_n4ms.npy
# 214/1000            optimal             2.3271300366837992e-08   26
# Saved file: ./Datasets/test1/iter_214_n4ms.npy
# 215/1000            optimal             3.17496413012633e-08     35
# Saved file: ./Datasets/test1/iter_215_n1ms.npy
# 216/1000            optimal             4.443208180909205e-08    3
# Saved file: ./Datasets/test1/iter_216_p0ms.npy
# 217/1000            optimal             2.123778245801795e-08    22
# Saved file: ./Datasets/test1/iter_217_n3ms.npy
# 218/1000            optimal             1.2367895872088245e-08   28
# Saved file: ./Datasets/test1/iter_218_n2ms.npy
# 219/1000            optimal             3.456707472411243e-08    8
# Saved file: ./Datasets/test1/iter_219_p0ms.npy
# 220/1000            optimal             4.889557317916014e-08    34
# Saved file: ./Datasets/test1/iter_220_p1ms.npy
# 221/1000            optimal             4.051975226192509e-08    5
# Saved file: ./Datasets/test1/iter_221_p0ms.npy
# 222/1000            optimal             4.5135443829121905e-08   34
# Saved file: ./Datasets/test1/iter_222_n2ms.npy
# 223/1000            optimal             2.6265729390437413e-08   35
# Saved file: ./Datasets/test1/iter_223_n1ms.npy
# 224/1000            optimal             9.418594868725778e-09    23
# Saved file: ./Datasets/test1/iter_224_n4ms.npy
# 225/1000            optimal             2.0089779841508227e-08   27
# Saved file: ./Datasets/test1/iter_225_n4ms.npy
# 226/1000            optimal             3.552917048114439e-08    20
# Saved file: ./Datasets/test1/iter_226_n3ms.npy
# 227/1000            optimal             1.1242879037496906e-08   30
# Saved file: ./Datasets/test1/iter_227_p3ms.npy
# 228/1000            optimal             4.843651952122569e-08    2
# Saved file: ./Datasets/test1/iter_228_p0ms.npy
# 229/1000            optimal             4.6923218907410415e-08   32
# Saved file: ./Datasets/test1/iter_229_p2ms.npy
# 230/1000            optimal             8.252981687813201e-09    24
# Saved file: ./Datasets/test1/iter_230_n4ms.npy
# 231/1000            optimal             3.508782610559736e-08    41
# Saved file: ./Datasets/test1/iter_231_n1ms.npy
# 232/1000            optimal             1.2879438589355854e-07   36
# Saved file: ./Datasets/test1/iter_232_n2ms.npy
# 233/1000            optimal             3.8810879158516724e-08   30
# Saved file: ./Datasets/test1/iter_233_p2ms.npy
# 234/1000            optimal             8.208718348759297e-09    29
# Saved file: ./Datasets/test1/iter_234_n3ms.npy
# 235/1000            optimal             3.564472117879939e-08    28
# Saved file: ./Datasets/test1/iter_235_n3ms.npy
# 236/1000            optimal             2.8801065876881447e-08   31
# Saved file: ./Datasets/test1/iter_236_p1ms.npy
# 237/1000            optimal             3.495615995430812e-08    23
# Saved file: ./Datasets/test1/iter_237_p1ms.npy
# 238/1000            optimal             1.1547688204566709e-08   26
# Saved file: ./Datasets/test1/iter_238_p2ms.npy
# 239/1000            optimal             3.9429114014012934e-08   4
# Saved file: ./Datasets/test1/iter_239_p0ms.npy
# 240/1000            optimal             1.08738287586957e-08     26
# Saved file: ./Datasets/test1/iter_240_p3ms.npy
# 241/1000            optimal             3.724804696039479e-08    32
# Saved file: ./Datasets/test1/iter_241_p2ms.npy
# 242/1000            optimal             2.4803541330656282e-08   24
# Saved file: ./Datasets/test1/iter_242_n4ms.npy
# 243/1000            optimal             2.045145989922795e-08    60
# Saved file: ./Datasets/test1/iter_243_n2ms.npy
# 244/1000            optimal             3.933460084989109e-08    56
# Saved file: ./Datasets/test1/iter_244_n1ms.npy
# 245/1000            optimal             9.231965968078927e-09    21
# Saved file: ./Datasets/test1/iter_245_p2ms.npy
# 246/1000            optimal             1.1379702180836738e-08   39
# Saved file: ./Datasets/test1/iter_246_p4ms.npy
# 247/1000            optimal             4.129364976564247e-08    33
# Saved file: ./Datasets/test1/iter_247_p1ms.npy
# 248/1000            optimal             2.260497815423605e-08    40
# Saved file: ./Datasets/test1/iter_248_n1ms.npy
# 249/1000            optimal             4.227066671327017e-08    33
# Saved file: ./Datasets/test1/iter_249_p1ms.npy
# 250/1000            optimal             4.4146561773855905e-08   6
# Saved file: ./Datasets/test1/iter_250_p0ms.npy
# 251/1000            optimal             3.653334705252246e-08    36
# Saved file: ./Datasets/test1/iter_251_n2ms.npy
# 252/1000            optimal             2.3880889895523444e-08   36
# Saved file: ./Datasets/test1/iter_252_n3ms.npy
# 253/1000            optimal             3.1141338922710003e-08   27
# Saved file: ./Datasets/test1/iter_253_n3ms.npy
# 254/1000            optimal             1.7403042257620807e-08   33
# Saved file: ./Datasets/test1/iter_254_p2ms.npy
# 255/1000            optimal             3.379343441501116e-08    42
# Saved file: ./Datasets/test1/iter_255_n1ms.npy
# 256/1000            optimal             3.6532238138474444e-08   4
# Saved file: ./Datasets/test1/iter_256_p0ms.npy
# 257/1000            optimal             1.5010461632382366e-08   34
# Saved file: ./Datasets/test1/iter_257_p4ms.npy
# 258/1000            optimal             1.5489079396481368e-08   21
# Saved file: ./Datasets/test1/iter_258_p2ms.npy
# 259/1000            optimal             4.598428520489394e-08    4
# Saved file: ./Datasets/test1/iter_259_p0ms.npy
# 260/1000            optimal             4.836282470980124e-08    2
# Saved file: ./Datasets/test1/iter_260_p0ms.npy
# 261/1000            optimal             3.163387760587338e-08    6
# Saved file: ./Datasets/test1/iter_261_p0ms.npy
# 262/1000            optimal             4.150913284725022e-08    46
# Saved file: ./Datasets/test1/iter_262_n3ms.npy
# 263/1000            optimal             7.278752161702605e-08    53
# Saved file: ./Datasets/test1/iter_263_n4ms.npy
# 264/1000            optimal             1.442161301147999e-08    26
# Saved file: ./Datasets/test1/iter_264_n3ms.npy
# 265/1000            optimal             2.0215180135177112e-08   19
# Saved file: ./Datasets/test1/iter_265_n4ms.npy
# 266/1000            optimal             3.1117675436450223e-08   24
# Saved file: ./Datasets/test1/iter_266_p1ms.npy
# 267/1000            optimal             9.033729310268774e-09    35
# Saved file: ./Datasets/test1/iter_267_p4ms.npy
# 268/1000            optimal             4.834530991937832e-08    1
# Saved file: ./Datasets/test1/iter_268_p0ms.npy
# 269/1000            optimal             4.2451442436191577e-08   5
# Saved file: ./Datasets/test1/iter_269_p0ms.npy
# 270/1000            optimal             4.7510000094596514e-08   32
# Saved file: ./Datasets/test1/iter_270_p1ms.npy
# 271/1000            optimal             3.807572044136317e-08    51
# Saved file: ./Datasets/test1/iter_271_n2ms.npy
# 272/1000            optimal             1.024761457564593e-08    26
# Saved file: ./Datasets/test1/iter_272_p3ms.npy
# 273/1000            optimal             3.8056322173619596e-08   32
# Saved file: ./Datasets/test1/iter_273_p1ms.npy
# 274/1000            optimal             3.763309778542015e-08    35
# Saved file: ./Datasets/test1/iter_274_p1ms.npy
# 275/1000            optimal             2.789250900315704e-08    31
# Saved file: ./Datasets/test1/iter_275_n4ms.npy
# 276/1000            optimal             1.7045758185432716e-08   44
# Saved file: ./Datasets/test1/iter_276_n1ms.npy
# 277/1000            optimal             8.356503468696922e-09    26
# Saved file: ./Datasets/test1/iter_277_n4ms.npy
# 278/1000            optimal             4.107500214533952e-08    47
# Saved file: ./Datasets/test1/iter_278_p1ms.npy
# Something went wrong with solve...
# 280/1000            optimal             3.839404941758663e-08    28
# Saved file: ./Datasets/test1/iter_280_p1ms.npy
# 281/1000            optimal             6.364679549760955e-09    33
# Saved file: ./Datasets/test1/iter_281_n4ms.npy
# 282/1000            optimal             2.929935860041827e-08    37
# Saved file: ./Datasets/test1/iter_282_n1ms.npy
# 283/1000            optimal             1.440425135726168e-08    39
# Saved file: ./Datasets/test1/iter_283_n2ms.npy
# 284/1000            optimal             7.89372584307868e-09     30
# Saved file: ./Datasets/test1/iter_284_n4ms.npy
# 285/1000            optimal             9.063538890951133e-09    25
# Saved file: ./Datasets/test1/iter_285_p4ms.npy
# 286/1000            optimal             1.2110761029776677e-08   56
# Saved file: ./Datasets/test1/iter_286_n1ms.npy
# 287/1000            optimal             1.6966942084860496e-08   39
# Saved file: ./Datasets/test1/iter_287_p4ms.npy
# Something went wrong with solve...
# 289/1000            optimal             1.7593224334952774e-05   64
# Failed
# 290/1000            optimal             2.4356723200959697e-08   27
# Saved file: ./Datasets/test1/iter_290_n4ms.npy
# Something went wrong with solve...
# 292/1000            optimal             4.001184747635759e-08    32
# Saved file: ./Datasets/test1/iter_292_p1ms.npy
# 293/1000            optimal             7.997680215847072e-09    30
# Saved file: ./Datasets/test1/iter_293_p3ms.npy
# 294/1000            optimal             3.822974900006964e-08    38
# Saved file: ./Datasets/test1/iter_294_n3ms.npy
# 295/1000            optimal             1.7827923495231886e-08   34
# Saved file: ./Datasets/test1/iter_295_n4ms.npy
# 296/1000            optimal             4.818433323165246e-08    1
# Saved file: ./Datasets/test1/iter_296_p0ms.npy
# 297/1000            optimal             2.5761092967535988e-08   38
# Saved file: ./Datasets/test1/iter_297_p2ms.npy
# 298/1000            optimal             2.3452803376122348e-08   38
# Saved file: ./Datasets/test1/iter_298_p2ms.npy
# 299/1000            optimal             1.3059223887419112e-08   29
# Saved file: ./Datasets/test1/iter_299_p4ms.npy
# 300/1000            optimal             4.450783961599738e-08    7
# Saved file: ./Datasets/test1/iter_300_p0ms.npy
# 301/1000            optimal             7.24252393453108e-09     21
# Saved file: ./Datasets/test1/iter_301_n4ms.npy
# 302/1000            optimal             7.994216944191365e-09    30
# Saved file: ./Datasets/test1/iter_302_n4ms.npy
# 303/1000            optimal             1.783833863615073e-08    36
# Saved file: ./Datasets/test1/iter_303_p4ms.npy
# 304/1000            optimal             4.1083669637576406e-08   36
# Saved file: ./Datasets/test1/iter_304_n2ms.npy
# 305/1000            optimal             1.4474102202087472e-08   31
# Saved file: ./Datasets/test1/iter_305_n2ms.npy
# 306/1000            optimal             2.0062245984925944e-08   56
# Saved file: ./Datasets/test1/iter_306_n1ms.npy
# 307/1000            optimal             9.812167616049695e-09    26
# Saved file: ./Datasets/test1/iter_307_n4ms.npy
# 308/1000            optimal             1.0206747765165815e-08   36
# Saved file: ./Datasets/test1/iter_308_p3ms.npy
# 309/1000            optimal             2.6120938776114465e-08   26
# Saved file: ./Datasets/test1/iter_309_n4ms.npy
# 310/1000            optimal             7.99401375751349e-09     26
# Saved file: ./Datasets/test1/iter_310_n4ms.npy
# 311/1000            optimal             1.5838387772763656e-08   53
# Saved file: ./Datasets/test1/iter_311_n1ms.npy
# 312/1000            optimal             2.050085663768119e-08    25
# Saved file: ./Datasets/test1/iter_312_n4ms.npy
# 313/1000            optimal             2.6177326805083043e-08   34
# Saved file: ./Datasets/test1/iter_313_p2ms.npy
# Something went wrong with solve...
# 315/1000            optimal             9.968090127990405e-09    25
# Saved file: ./Datasets/test1/iter_315_p4ms.npy
# 316/1000            optimal             3.15180286178853e-08     29
# Saved file: ./Datasets/test1/iter_316_p1ms.npy
# 317/1000            optimal             9.445257908368041e-09    23
# Saved file: ./Datasets/test1/iter_317_p3ms.npy
# 318/1000            optimal             1.6807166050160758e-08   24
# Saved file: ./Datasets/test1/iter_318_p1ms.npy
# 319/1000            optimal             3.8499482219667355e-08   48
# Saved file: ./Datasets/test1/iter_319_n1ms.npy
# 320/1000            optimal             6.441089273991703e-08    43
# Saved file: ./Datasets/test1/iter_320_n2ms.npy
# 321/1000            optimal             1.4499517337121635e-08   33
# Saved file: ./Datasets/test1/iter_321_n2ms.npy
# 322/1000            optimal             2.568299580078942e-08    46
# Saved file: ./Datasets/test1/iter_322_p3ms.npy
# 323/1000            optimal             1.950950367872195e-08    21
# Saved file: ./Datasets/test1/iter_323_n4ms.npy
# 324/1000            optimal             4.333702407037539e-08    57
# Saved file: ./Datasets/test1/iter_324_n2ms.npy
# 325/1000            optimal             1.7676758030763557e-08   42
# Saved file: ./Datasets/test1/iter_325_p2ms.npy
# 326/1000            optimal             2.566208007956778e-08    30
# Saved file: ./Datasets/test1/iter_326_n4ms.npy
# 327/1000            optimal             1.1388187230332813e-08   29
# Saved file: ./Datasets/test1/iter_327_n2ms.npy
# 328/1000            optimal             4.8331693283920266e-08   1
# Saved file: ./Datasets/test1/iter_328_p0ms.npy
# 329/1000            optimal             8.903050855421984e-09    24
# Saved file: ./Datasets/test1/iter_329_p2ms.npy
# 330/1000            optimal             4.6415135443995615e-08   3
# Saved file: ./Datasets/test1/iter_330_p0ms.npy
# 331/1000            optimal             4.667726742019888e-08    27
# Saved file: ./Datasets/test1/iter_331_p1ms.npy
# 332/1000            optimal             3.7529244116177e-08      26
# Saved file: ./Datasets/test1/iter_332_n3ms.npy
# 333/1000            optimal             1.9670318453603265e-08   29
# Saved file: ./Datasets/test1/iter_333_n4ms.npy
# 334/1000            optimal             5.7461086167713405e-08   44
# Saved file: ./Datasets/test1/iter_334_n2ms.npy
# 335/1000            optimal             2.0813135429273855e-08   42
# Saved file: ./Datasets/test1/iter_335_n3ms.npy
# 336/1000            optimal             5.2650624643340924e-08   25
# Saved file: ./Datasets/test1/iter_336_n4ms.npy
# 337/1000            optimal             1.932688134112243e-08    40
# Saved file: ./Datasets/test1/iter_337_n1ms.npy
# 338/1000            optimal             3.6596126062050966e-08   43
# Saved file: ./Datasets/test1/iter_338_p1ms.npy
# 339/1000            optimal             6.432182765804508e-09    22
# Saved file: ./Datasets/test1/iter_339_n4ms.npy
# 340/1000            optimal             1.2588059080405743e-08   22
# Saved file: ./Datasets/test1/iter_340_p3ms.npy
# 341/1000            optimal             1.027712873548782e-08    30
# Saved file: ./Datasets/test1/iter_341_p4ms.npy
# 342/1000            optimal             1.5127180747294224e-08   25
# Saved file: ./Datasets/test1/iter_342_n4ms.npy
# 343/1000            optimal             4.264984556529013e-08    28
# Saved file: ./Datasets/test1/iter_343_p2ms.npy
# 344/1000            optimal             4.685313209933187e-08    38
# Saved file: ./Datasets/test1/iter_344_n2ms.npy
# 345/1000            optimal             3.542089533287879e-08    25
# Saved file: ./Datasets/test1/iter_345_p1ms.npy
# 346/1000            optimal             2.5732664781806403e-08   40
# Saved file: ./Datasets/test1/iter_346_n3ms.npy
# 347/1000            optimal             2.05008566376811e-08     23
# Saved file: ./Datasets/test1/iter_347_n4ms.npy
# 348/1000            optimal             3.9541564543680774e-08   29
# Saved file: ./Datasets/test1/iter_348_p1ms.npy
# 349/1000            optimal             2.959467273526966e-08    27
# Saved file: ./Datasets/test1/iter_349_p1ms.npy
# Something went wrong with solve...
# 351/1000            optimal             3.1868346785877164e-08   33
# Saved file: ./Datasets/test1/iter_351_p2ms.npy
# 352/1000            optimal             1.473132310823955e-08    27
# Saved file: ./Datasets/test1/iter_352_p4ms.npy
# 353/1000            optimal             2.237332318807035e-08    34
# Saved file: ./Datasets/test1/iter_353_p3ms.npy
# 354/1000            optimal             1.2224752097465355e-08   34
# Saved file: ./Datasets/test1/iter_354_p4ms.npy
# 355/1000            optimal             2.4153672828839828e-08   43
# Saved file: ./Datasets/test1/iter_355_p4ms.npy
# 356/1000            optimal             6.609327505258264e-08    35
# Saved file: ./Datasets/test1/iter_356_p4ms.npy
# 357/1000            optimal             6.509556801508892e-08    35
# Saved file: ./Datasets/test1/iter_357_n3ms.npy
# 358/1000            optimal             2.0502092992242714e-08   24
# Saved file: ./Datasets/test1/iter_358_n4ms.npy
# 359/1000            optimal             2.1870841651130135e-08   34
# Saved file: ./Datasets/test1/iter_359_n4ms.npy
# 360/1000            optimal             1.8923611255053306e-08   42
# Saved file: ./Datasets/test1/iter_360_p2ms.npy
# 361/1000            optimal             5.6349881891665664e-08   63
# Saved file: ./Datasets/test1/iter_361_n2ms.npy
# 362/1000            optimal             5.568567330736457e-08    52
# Saved file: ./Datasets/test1/iter_362_n1ms.npy
# 363/1000            optimal             2.5408843647819744e-08   23
# Saved file: ./Datasets/test1/iter_363_p1ms.npy
# 364/1000            optimal             2.5748083305506434e-08   10
# Saved file: ./Datasets/test1/iter_364_p0ms.npy
# 365/1000            optimal             1.3548593093030949e-08   30
# Saved file: ./Datasets/test1/iter_365_p4ms.npy
# 366/1000            optimal             3.7251495630623106e-08   34
# Saved file: ./Datasets/test1/iter_366_n1ms.npy
# 367/1000            optimal             4.542082105669305e-08    3
# Saved file: ./Datasets/test1/iter_367_p0ms.npy
# 368/1000            optimal             8.85107962655201e-09     32
# Saved file: ./Datasets/test1/iter_368_n3ms.npy
# 369/1000            optimal             3.9363707215326995e-08   38
# Saved file: ./Datasets/test1/iter_369_p2ms.npy
# 370/1000            optimal             3.736620674145237e-08    35
# Saved file: ./Datasets/test1/iter_370_p2ms.npy
# 371/1000            optimal             5.1761585574859226e-08   48
# Saved file: ./Datasets/test1/iter_371_n2ms.npy
# 372/1000            optimal             4.53937799561476e-08     4
# Saved file: ./Datasets/test1/iter_372_p0ms.npy
# 373/1000            optimal             1.9875277146280396e-08   39
# Saved file: ./Datasets/test1/iter_373_p4ms.npy
# 374/1000            optimal             1.218656095016629e-08    27
# Saved file: ./Datasets/test1/iter_374_p2ms.npy
# 375/1000            optimal             1.142998244165832e-08    23
# Saved file: ./Datasets/test1/iter_375_p3ms.npy
# Something went wrong with solve...
# 377/1000            optimal             1.1363538061875318e-08   33
# Saved file: ./Datasets/test1/iter_377_n2ms.npy
# 378/1000            optimal             2.8641190574212088e-08   6
# Saved file: ./Datasets/test1/iter_378_p0ms.npy
# 379/1000            optimal             3.6801841288682507e-08   34
# Saved file: ./Datasets/test1/iter_379_n2ms.npy
# 380/1000            optimal             1.2732108659313367e-08   29
# Saved file: ./Datasets/test1/iter_380_p4ms.npy
# 381/1000            optimal             1.2794421752375075e-08   25
# Saved file: ./Datasets/test1/iter_381_p3ms.npy
# ...
# Saved file: ./Datasets/test1/iter_873_n4ms.npy
# 874/1000            optimal             2.0224131744742272e-08   26
# Saved file: ./Datasets/test1/iter_874_n4ms.npy
# 875/1000            optimal             1.2593395278190631e-08   28
# Saved file: ./Datasets/test1/iter_875_n4ms.npy
# 876/1000            optimal             1.0322101587515635e-08   32
# Saved file: ./Datasets/test1/iter_876_p4ms.npy
# 877/1000            optimal             3.8119303871770544e-08   38
# Saved file: ./Datasets/test1/iter_877_n1ms.npy
# 878/1000            optimal             3.627262133086158e-08    33
# Saved file: ./Datasets/test1/iter_878_p1ms.npy
# 879/1000            optimal             1.2865533115526697e-08   28
# Saved file: ./Datasets/test1/iter_879_p3ms.npy
# 880/1000            optimal             1.0350477544194121e-08   33
# Saved file: ./Datasets/test1/iter_880_p4ms.npy
# 881/1000            optimal             3.30737785843454e-08     41
# Saved file: ./Datasets/test1/iter_881_n1ms.npy
# 882/1000            optimal             3.031653155965891e-08    72
# Saved file: ./Datasets/test1/iter_882_p2ms.npy
# 883/1000            optimal             1.182433643181036e-08    28
# Saved file: ./Datasets/test1/iter_883_p3ms.npy
# 884/1000            optimal             2.3326897693669633e-08   34
# Saved file: ./Datasets/test1/iter_884_p4ms.npy
# 885/1000            optimal             1.008752419524143e-08    26
# Saved file: ./Datasets/test1/iter_885_n3ms.npy
# 886/1000            optimal             2.2779992629589042e-08   42
# Saved file: ./Datasets/test1/iter_886_n1ms.npy
# 887/1000            optimal             4.344763002880249e-08    5
# Saved file: ./Datasets/test1/iter_887_p0ms.npy
# Something went wrong with solve...
# 889/1000            optimal             1.1636079774281454e-08   28
# Saved file: ./Datasets/test1/iter_889_p3ms.npy
# 890/1000            optimal             3.359569049136576e-08    7
# Saved file: ./Datasets/test1/iter_890_p0ms.npy
# Something went wrong with solve...
# 892/1000            optimal             4.542105271790363e-08    3
# Saved file: ./Datasets/test1/iter_892_p0ms.npy
# 893/1000            optimal             1.5845670038630614e-08   24
# Saved file: ./Datasets/test1/iter_893_n4ms.npy
# 894/1000            optimal             1.5115198744679816e-08   31
# Saved file: ./Datasets/test1/iter_894_n3ms.npy
# 895/1000            optimal             2.3711744187957e-08      8
# Saved file: ./Datasets/test1/iter_895_p0ms.npy
# 896/1000            optimal             3.62535909361625e-08     43
# Saved file: ./Datasets/test1/iter_896_p1ms.npy
# 897/1000            optimal             8.50990075838773e-09     23
# Saved file: ./Datasets/test1/iter_897_p3ms.npy
# 898/1000            optimal             1.0936262338818228e-08   23
# Saved file: ./Datasets/test1/iter_898_p3ms.npy
# 899/1000            optimal             4.217650621458978e-08    42
# Saved file: ./Datasets/test1/iter_899_n2ms.npy
# 900/1000            optimal             3.531547630870182e-08    28
# Saved file: ./Datasets/test1/iter_900_n3ms.npy
# Something went wrong with solve...
# 902/1000            optimal             1.2286517105370393e-08   30
# Saved file: ./Datasets/test1/iter_902_p3ms.npy
# 903/1000            optimal             9.446273689848729e-09    25
# Saved file: ./Datasets/test1/iter_903_p3ms.npy
# 904/1000            optimal             2.2341725285352384e-08   23
# Saved file: ./Datasets/test1/iter_904_p3ms.npy
# Something went wrong with solve...
# 906/1000            optimal             9.481014420649204e-09    27
# Saved file: ./Datasets/test1/iter_906_p4ms.npy
# Something went wrong with solve...
# 908/1000            optimal             1.3765703173096353e-08   29
# Saved file: ./Datasets/test1/iter_908_p4ms.npy
# 909/1000            optimal             1.746003579903243e-08    29
# Saved file: ./Datasets/test1/iter_909_n1ms.npy
# 910/1000            optimal             1.0317549061460526e-08   31
# Saved file: ./Datasets/test1/iter_910_p4ms.npy
# 911/1000            optimal             8.973480323228459e-09    25
# Saved file: ./Datasets/test1/iter_911_p4ms.npy
# 912/1000            optimal             1.0165115849438177e-08   23
# Saved file: ./Datasets/test1/iter_912_p3ms.npy
# 913/1000            optimal             3.356758134469099e-08    33
# Saved file: ./Datasets/test1/iter_913_n1ms.npy
# 914/1000            optimal             1.3198632518415952e-08   24
# Saved file: ./Datasets/test1/iter_914_p2ms.npy
# 915/1000            optimal             1.0289815301880266e-08   25
# Saved file: ./Datasets/test1/iter_915_p3ms.npy
# 916/1000            optimal             4.531993585807815e-08    3
# Saved file: ./Datasets/test1/iter_916_p0ms.npy
# 917/1000            optimal             6.2672929589349526e-09   24
# Saved file: ./Datasets/test1/iter_917_n4ms.npy
# 918/1000            optimal             1.0087240387761148e-08   26
# Saved file: ./Datasets/test1/iter_918_n3ms.npy
# 919/1000            optimal             2.8051047758495488e-08   34
# Saved file: ./Datasets/test1/iter_919_n3ms.npy
# 920/1000            optimal             1.548206169550464e-08    35
# Saved file: ./Datasets/test1/iter_920_n2ms.npy
# 921/1000            optimal             1.0319887428085442e-08   23
# Saved file: ./Datasets/test1/iter_921_p3ms.npy
# 922/1000            optimal             3.6641924813578534e-08   31
# Saved file: ./Datasets/test1/iter_922_p1ms.npy
# 923/1000            optimal             4.2722068690671365e-08   41
# Saved file: ./Datasets/test1/iter_923_n2ms.npy
# 924/1000            optimal             4.3721318049703047e-08   56
# Saved file: ./Datasets/test1/iter_924_n2ms.npy
# 925/1000            optimal             4.281560664362003e-08    28
# Saved file: ./Datasets/test1/iter_925_p1ms.npy
# 926/1000            optimal             1.1232308216219574e-08   26
# Saved file: ./Datasets/test1/iter_926_n2ms.npy
# 927/1000            optimal             1.196598077527974e-08    25
# Saved file: ./Datasets/test1/iter_927_n4ms.npy
# 928/1000            optimal             3.698160598564459e-08    40
# Saved file: ./Datasets/test1/iter_928_n1ms.npy
# 929/1000            optimal             8.255920275272533e-09    26
# Saved file: ./Datasets/test1/iter_929_n4ms.npy
# 930/1000            optimal             3.4650955303843516e-08   9
# Saved file: ./Datasets/test1/iter_930_p0ms.npy
# 931/1000            optimal             4.04453511691925e-08     36
# Saved file: ./Datasets/test1/iter_931_n2ms.npy
# 932/1000            optimal             4.6411824509992386e-08   3
# Saved file: ./Datasets/test1/iter_932_p0ms.npy
# 933/1000            optimal             4.872780276863834e-08    54
# Saved file: ./Datasets/test1/iter_933_p1ms.npy
# 934/1000            optimal             1.1604078853582113e-08   29
# Saved file: ./Datasets/test1/iter_934_p4ms.npy
# 935/1000            optimal             8.414681026183246e-09    24
# Saved file: ./Datasets/test1/iter_935_p4ms.npy
# 936/1000            optimal             3.451221870728435e-08    45
# Saved file: ./Datasets/test1/iter_936_n2ms.npy
# 937/1000            optimal             8.374582524601766e-09    31
# Saved file: ./Datasets/test1/iter_937_p4ms.npy
# 938/1000            optimal             2.2373672621682396e-08   5
# Saved file: ./Datasets/test1/iter_938_p0ms.npy
# 939/1000            optimal             2.957016432282771e-08    47
# Saved file: ./Datasets/test1/iter_939_n1ms.npy
# 940/1000            optimal             4.674589448206165e-08    42
# Saved file: ./Datasets/test1/iter_940_n2ms.npy
# 941/1000            optimal             1.21169132170601e-08     26
# Saved file: ./Datasets/test1/iter_941_p3ms.npy
# 942/1000            optimal             6.432182435559343e-09    29
# Saved file: ./Datasets/test1/iter_942_n4ms.npy
# 943/1000            optimal             2.662206577416208e-08    33
# Saved file: ./Datasets/test1/iter_943_p2ms.npy
# 944/1000            optimal             1.980707405268006e-08    41
# Saved file: ./Datasets/test1/iter_944_n4ms.npy
# 945/1000            optimal             4.123457916890959e-08    40
# Saved file: ./Datasets/test1/iter_945_n2ms.npy
# Something went wrong with solve...
# 947/1000            optimal             8.572198156748568e-09    27
# Saved file: ./Datasets/test1/iter_947_p3ms.npy
# 948/1000            optimal             1.9319192690016396e-08   29
# Saved file: ./Datasets/test1/iter_948_n4ms.npy
# 949/1000            optimal             4.451422333925423e-08    6
# Saved file: ./Datasets/test1/iter_949_p0ms.npy
# 950/1000            optimal             3.288418848580234e-08    33
# Saved file: ./Datasets/test1/iter_950_p2ms.npy
# 951/1000            optimal             3.753630120535023e-08    32
# Saved file: ./Datasets/test1/iter_951_p1ms.npy
# 952/1000            optimal             4.079638038138906e-08    38
# Saved file: ./Datasets/test1/iter_952_p1ms.npy
# 953/1000            optimal             4.8416748509912274e-08   1
# Saved file: ./Datasets/test1/iter_953_p0ms.npy
# Something went wrong with solve...
# 955/1000            optimal             2.6098332370076046e-08   32
# Saved file: ./Datasets/test1/iter_955_p3ms.npy
# 956/1000            optimal             9.572939397243898e-09    33
# Saved file: ./Datasets/test1/iter_956_p4ms.npy
# 957/1000            optimal             1.558384173621818e-08    77
# Saved file: ./Datasets/test1/iter_957_n3ms.npy
# 958/1000            optimal             2.1666602092244006e-08   27
# Saved file: ./Datasets/test1/iter_958_p1ms.npy
# Something went wrong with solve...
# 960/1000            optimal             3.7674605556957e-08      24
# Saved file: ./Datasets/test1/iter_960_p1ms.npy
# 961/1000            optimal             4.430211358478839e-08    34
# Saved file: ./Datasets/test1/iter_961_p1ms.npy
# 962/1000            optimal             8.150633676933826e-09    34
# Saved file: ./Datasets/test1/iter_962_p4ms.npy
# 963/1000            optimal             9.054739438966017e-09    27
# Saved file: ./Datasets/test1/iter_963_n3ms.npy
# 964/1000            optimal             1.235121297382194e-08    34
# Saved file: ./Datasets/test1/iter_964_p4ms.npy
# 965/1000            optimal             3.785709144625754e-08    37
# Saved file: ./Datasets/test1/iter_965_p2ms.npy
# 966/1000            optimal             1.261642010861768e-08    19
# Saved file: ./Datasets/test1/iter_966_n3ms.npy
# 967/1000            optimal             5.3620573959071875e-08   30
# Saved file: ./Datasets/test1/iter_967_p2ms.npy
# 968/1000            optimal             1.084109843392759e-08    26
# Saved file: ./Datasets/test1/iter_968_p3ms.npy
# 969/1000            optimal             1.1087357240194238e-08   31
# Saved file: ./Datasets/test1/iter_969_p4ms.npy
# 970/1000            optimal             3.40676335873773e-08     63
# Saved file: ./Datasets/test1/iter_970_n1ms.npy
# 971/1000            optimal             2.6101668123064068e-08   30
# Saved file: ./Datasets/test1/iter_971_p4ms.npy
# 972/1000            optimal             2.956279786536295e-08    36
# Saved file: ./Datasets/test1/iter_972_p4ms.npy
# 973/1000            optimal             4.443546825844201e-08    3
# Saved file: ./Datasets/test1/iter_973_p0ms.npy
# 974/1000            optimal             2.357861038286844e-08    27
# Saved file: ./Datasets/test1/iter_974_p1ms.npy
# 975/1000            optimal             1.2375399187928396e-08   27
# Saved file: ./Datasets/test1/iter_975_p2ms.npy
# 976/1000            optimal             1.587389689042417e-08    30
# Saved file: ./Datasets/test1/iter_976_p2ms.npy
# 977/1000            optimal             2.3871903793724465e-08   35
# Saved file: ./Datasets/test1/iter_977_n2ms.npy
# 978/1000            optimal             1.258093114861016e-08    29
# Saved file: ./Datasets/test1/iter_978_p2ms.npy
# 979/1000            optimal             3.989478854115544e-08    74
# Saved file: ./Datasets/test1/iter_979_n2ms.npy
# 980/1000            optimal             1.0389529772998093e-07   38
# Saved file: ./Datasets/test1/iter_980_n2ms.npy
# 981/1000            optimal             1.5484882802272707e-08   28
# Saved file: ./Datasets/test1/iter_981_p4ms.npy
# 982/1000            optimal             1.1091121535885638e-08   26
# Saved file: ./Datasets/test1/iter_982_p3ms.npy
# 983/1000            optimal             7.316182991428366e-09    24
# Saved file: ./Datasets/test1/iter_983_n4ms.npy
# 984/1000            optimal             3.455878457474489e-08    5
# Saved file: ./Datasets/test1/iter_984_p0ms.npy
# 985/1000            optimal             2.4414611651244857e-08   82
# Saved file: ./Datasets/test1/iter_985_n2ms.npy
# 986/1000            optimal             3.858219849040129e-08    34
# Saved file: ./Datasets/test1/iter_986_n3ms.npy
# 987/1000            optimal             3.754516162189829e-08    36
# Saved file: ./Datasets/test1/iter_987_p1ms.npy
# 988/1000            optimal             2.2084822401291443e-08   46
# Saved file: ./Datasets/test1/iter_988_n1ms.npy
# Something went wrong with solve...
# 990/1000            optimal             3.947057672932474e-08    23
# Saved file: ./Datasets/test1/iter_990_p1ms.npy
# 991/1000            optimal             4.8230387525441586e-08   2
# Saved file: ./Datasets/test1/iter_991_p0ms.npy
# 992/1000            optimal             2.4254354010204236e-08   33
# Saved file: ./Datasets/test1/iter_992_p4ms.npy
# Something went wrong with solve...
# Something went wrong with solve...
# 995/1000            optimal             9.642470217518478e-09    20
# Saved file: ./Datasets/test1/iter_995_p3ms.npy
# 996/1000            optimal             9.75873396610892e-09     26
# Saved file: ./Datasets/test1/iter_996_n2ms.npy
# 997/1000            optimal             1.3009472249042644e-08   38
# Saved file: ./Datasets/test1/iter_997_n1ms.npy
# 998/1000            optimal             9.442184400918515e-09    32
# Saved file: ./Datasets/test1/iter_998_p4ms.npy
# 999/1000            optimal             1.3367049285059995e-07   42
# Saved file: ./Datasets/test1/iter_999_n2ms.npy
# 1000/1000           optimal             2.426208338739973e-08    30
# Saved file: ./Datasets/test1/iter_1000_n4ms.npy
# ---------------------------------------------------------------------
# Batch finished.
# Percetage sucessful solves: 93 %

# %%
# m_sim = m.clone()

# m_sim.q.pprint()

# round(success_solves/iterations*100)

# %%
# print(results.solver.status) # tells you if the solver had any errors/ warnings
# print(results.solver.termination_condition) # tells you if the solution was (locally) optimal, feasible, or neither.

# penalty_sum = 0
# for n in range(1,N+1):
#     for gc in ground_constraints:
#         penalty_sum += m.ground_penalty[n,gc].value
#     for jc in joint_constraints:
#         for j in joints:
#             penalty_sum += m.joint_penalty[n,j,jc].value


# print()
# print("Penalty:   ", penalty_sum)
# print("Solve Time: %.2f" %solve_time, "s", sep="")
# # m.pprint()

# %%
#animate it
import matplotlib.pyplot as plt
import matplotlib.animation as ani
from IPython.display import HTML
# %matplotlib inline

fig1, ax1 = plt.subplots(1,1) #create axes
ax1.set_aspect('equal')

def plot_robot(i,m_sim,ax): #update function for animation
    ax.clear()
    ax.set_xlim([-5.0,5.0])
    ax.set_ylim([0,4])
    
    #plot body
    body_xb = m_sim.q[i,'x'].value - 0.5*m_sim.len[('body',1)]*cos(m_sim.q[i,'theta_b'].value)
    body_yb = m_sim.q[i,'y'].value - 0.5*m_sim.len[('body',1)]*sin(m_sim.q[i,'theta_b'].value)
    body_xf = m_sim.q[i,'x'].value + 0.5*m_sim.len[('body',1)]*cos(m_sim.q[i,'theta_b'].value)
    body_yf = m_sim.q[i,'y'].value + 0.5*m_sim.len[('body',1)]*sin(m_sim.q[i,'theta_b'].value)  
    ax.plot([body_xb,body_xf],[body_yb,body_yf],color='xkcd:black')
      
    #plot leg 1
    thA1 = m_sim.q[i,'theta_b'].value+m_sim.q[i,'theta_lt'].value
    thA2 = thA1+m_sim.q[i,'theta_lb'].value
    leg1_xt = m_sim.q[i,'x'].value
    leg1_yt = m_sim.q[i,'y'].value
    leg1_xb = m_sim.q[i,'x'].value + m_sim.len[('leg',1)]*sin(thA1)
    leg1_yb = m_sim.q[i,'y'].value - m_sim.len[('leg',1)]*cos(thA1)
    ax.plot([leg1_xt,leg1_xb],[leg1_yt,leg1_yb],color='xkcd:black')
    
    #plot leg 2
    leg2_xt = leg1_xb
    leg2_yt = leg1_yb
    leg2_xb = leg1_xb + m_sim.len[('leg',2)]*sin(thA2)
    leg2_yb = leg1_yb - m_sim.len[('leg',2)]*cos(thA2)
    ax.plot([leg2_xt,leg2_xb],[leg2_yt,leg2_yb],color='xkcd:black')
    
update = lambda i: plot_robot(i,m_sim,ax1) #lambdify update function

animate = ani.FuncAnimation(fig1,update,range(1,N+1),interval = 50,repeat=True)
plt.close(animate._fig)

HTML(animate.to_html5_video()) #you need to convert the animation to HTML5 to embed it in the notebook
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
# m.q.pprint()

# %%
# qx_ar = np.array([m.q[i,'x'].value for i in range(1, N+1)])
# qy_ar = np.array([m.q[i,'y'].value for i in range(1, N+1)])
# qthb_ar = np.array([m.q[i,'theta_b'].value for i in range(1, N+1)])
# qthlt_ar = np.array([m.q[i,'theta_lt'].value for i in range(1, N+1)])
# qthlb_ar = np.array([m.q[i,'theta_lb'].value for i in range(1, N+1)])

# vx_avg = 0.0
# i = 1
# if vx_avg > 0:
#     vx_avg_str = "p" + str(int(vx_avg))
# elif vx_avg < 0:
#     vx_avg_str = "n" + str(abs(int(vx_avg)))
# else: 
#     vx_avg_str = str(int(vx_avg)) 
    
# filename = "iter_" + str(i) + "_" + vx_avg_str + "ms.npy"

# filepath = "./Datasets/test1/"

# file = filepath + filename

# np.save(file, [qx_ar, qy_ar, qthb_ar, qthlt_ar, qthlb_ar, vx_avg])

# %%
one, two, three, four, five, six = np.load(file, allow_pickle = True)

# %%
# six
